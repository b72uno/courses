# %% [markdown]
# # Anna KaRNNa
#
# In this notebook, I'll build a character-wise RNN trained on Anna Karenina, one of my all-time favorite books. It'll be able to generate new text based on the text from the book.
#
# This network is based off of Andrej Karpathy's [post on RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/) and [implementation in Torch](https://github.com/karpathy/char-rnn). Also, some information [here at r2rt](http://r2rt.com/recurrent-neural-networks-in-tensorflow-ii.html) and from [Sherjil Ozair](https://github.com/sherjilozair/char-rnn-tensorflow) on GitHub. Below is the general architecture of the character-wise RNN.
#
# <img src="assets/charseq.jpeg" width="500">

# %%
import time
from collections import namedtuple

import numpy as np
import tensorflow as tf

# %% [markdown]
# First we'll load the text file and convert it into integers for our network to use. Here I'm creating a couple dictionaries to convert the characters to and from integers. Encoding the characters as integers makes it easier to use as input in the network.

# %%
with open('anna.txt', 'r') as f:
    text=f.read()
vocab = set(text)
vocab_to_int = {c: i for i, c in enumerate(vocab)}
int_to_vocab = dict(enumerate(vocab))
encoded = np.array([vocab_to_int[c] for c in text], dtype=np.int32)

# %% [markdown]
# Let's check out the first 100 characters, make sure everything is peachy. According to the [American Book Review](http://americanbookreview.org/100bestlines.asp), this is the 6th best first line of a book ever.

# %%
text[:100]
# Out:
# 'Chapter 1\n\n\nHappy families are all alike; every unhappy family is unhappy in its own\nway.\n\nEverythin'

# %% [markdown]
# And we can see the characters encoded as integers.

# %%
encoded[:100]
# Out:
# array([63, 43, 74, 72, 82,  6, 36, 45, 10, 58, 58, 58, 70, 74, 72, 72,  4,
#        45, 14, 74, 23,  9, 34,  9,  6, 71, 45, 74, 36,  6, 45, 74, 34, 34,
#        45, 74, 34,  9, 12,  6, 27, 45,  6, 75,  6, 36,  4, 45, 13, 51, 43,
#        74, 72, 72,  4, 45, 14, 74, 23,  9, 34,  4, 45,  9, 71, 45, 13, 51,
#        43, 74, 72, 72,  4, 45,  9, 51, 45,  9, 82, 71, 45, 16, 81, 51, 58,
#        81, 74,  4, 15, 58, 58, 60, 75,  6, 36,  4, 82, 43,  9, 51], dtype=int32)

# %% [markdown]
# Since the network is working with individual characters, it's similar to a classification problem in which we are trying to predict the next character from the previous text.  Here's how many 'classes' our network has to pick from.

# %%
len(vocab)
# Out:
# 83

# %% [markdown]
# ## Making training mini-batches
#
# Here is where we'll make our mini-batches for training. Remember that we want our batches to be multiple sequences of some desired number of sequence steps. Considering a simple example, our batches would look like this:
#
# <img src="assets/sequence_batching@1x.png" width=500px>
#
#
# <br>
# We have our text encoded as integers as one long array in `encoded`. Let's create a function that will give us an iterator for our batches. I like using [generator functions](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/) to do this. Then we can pass `encoded` into this function and get our batch generator.
#
# The first thing we need to do is discard some of the text so we only have completely full batches. Each batch contains $N \times M$ characters, where $N$ is the batch size (the number of sequences) and $M$ is the number of steps. Then, to get the number of batches we can make from some array `arr`, you divide the length of `arr` by the batch size. Once you know the number of batches and the batch size, you can get the total number of characters to keep.
#
# After that, we need to split `arr` into $N$ sequences. You can do this using `arr.reshape(size)` where `size` is a tuple containing the dimensions sizes of the reshaped array. We know we want $N$ sequences (`n_seqs` below), let's make that the size of the first dimension. For the second dimension, you can use `-1` as a placeholder in the size, it'll fill up the array with the appropriate data for you. After this, you should have an array that is $N \times (M * K)$ where $K$ is the number of batches.
#
# Now that we have this array, we can iterate through it to get our batches. The idea is each batch is a $N \times M$ window on the array. For each subsequent batch, the window moves over by `n_steps`. We also want to create both the input and target arrays. Remember that the targets are the inputs shifted over one character. You'll usually see the first input character used as the last target character, so something like this:
# ```python
# y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
# ```
# where `x` is the input batch and `y` is the target batch.
#
# The way I like to do this window is use `range` to take steps of size `n_steps` from $0$ to `arr.shape[1]`, the total number of steps in each sequence. That way, the integers you get from `range` always point to the start of a batch, and each window is `n_steps` wide.

# %%
def get_batches(arr, n_seqs, n_steps):
    '''Create a generator that returns batches of size
       n_seqs x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       n_seqs: Batch size, the number of sequences per batch
       n_steps: Number of sequence steps per batch
    '''
    # Get the number of characters per batch and number of batches we can make
    characters_per_batch = n_seqs * n_steps
    n_batches = len(arr)//characters_per_batch
    
    # Keep only enough characters to make full batches
    arr = arr[:n_batches * characters_per_batch]
    
    # Reshape into n_seqs rows
    arr = arr.reshape((n_seqs, -1))
    
    for n in range(0, arr.shape[1], n_steps):
        # The features
        x = arr[:, n:n+n_steps]
        # The targets, shifted by one
        y = np.zeros_like(x)
        y[:, :-1], y[:, -1] = x[:, 1:], x[:, 0]
        yield x, y

# %% [markdown]
# Now I'll make my data sets and we can check out what's going on here. Here I'm going to use a batch size of 10 and 50 sequence steps.

# %%
batches = get_batches(encoded, 10, 50)
x, y = next(batches)

# %%
print('x\n', x[:10, :10])
print('\ny\n', y[:10, :10])
# Out:
# x
#  [[63 43 74 72 82  6 36 45 10 58]
#  [45 74 23 45 51 16 82 45  5 16]
#  [75  9 51 15 58 58 24  2  6 71]
#  [51 45 76 13 36  9 51  5 45 43]
#  [45  9 82 45  9 71 69 45 71  9]
#  [45 17 82 45 81 74 71 58 16 51]
#  [43  6 51 45 62 16 23  6 45 14]
#  [27 45 20 13 82 45 51 16 81 45]
#  [82 45  9 71 51  1 82 15 45 35]
#  [45 71 74  9 76 45 82 16 45 43]]
#
# y
#  [[43 74 72 82  6 36 45 10 58 58]
#  [74 23 45 51 16 82 45  5 16  9]
#  [ 9 51 15 58 58 24  2  6 71 69]
#  [45 76 13 36  9 51  5 45 43  9]
#  [ 9 82 45  9 71 69 45 71  9 36]
#  [17 82 45 81 74 71 58 16 51 34]
#  [ 6 51 45 62 16 23  6 45 14 16]
#  [45 20 13 82 45 51 16 81 45 71]
#  [45  9 71 51  1 82 15 45 35 43]
#  [71 74  9 76 45 82 16 45 43  6]]

# %% [markdown]
# If you implemented `get_batches` correctly, the above output should look something like
# ```
# x
#  [[55 63 69 22  6 76 45  5 16 35]
#  [ 5 69  1  5 12 52  6  5 56 52]
#  [48 29 12 61 35 35  8 64 76 78]
#  [12  5 24 39 45 29 12 56  5 63]
#  [ 5 29  6  5 29 78 28  5 78 29]
#  [ 5 13  6  5 36 69 78 35 52 12]
#  [63 76 12  5 18 52  1 76  5 58]
#  [34  5 73 39  6  5 12 52 36  5]
#  [ 6  5 29 78 12 79  6 61  5 59]
#  [ 5 78 69 29 24  5  6 52  5 63]]
#
# y
#  [[63 69 22  6 76 45  5 16 35 35]
#  [69  1  5 12 52  6  5 56 52 29]
#  [29 12 61 35 35  8 64 76 78 28]
#  [ 5 24 39 45 29 12 56  5 63 29]
#  [29  6  5 29 78 28  5 78 29 45]
#  [13  6  5 36 69 78 35 52 12 43]
#  [76 12  5 18 52  1 76  5 58 52]
#  [ 5 73 39  6  5 12 52 36  5 78]
#  [ 5 29 78 12 79  6 61  5 59 63]
#  [78 69 29 24  5  6 52  5 63 76]]
#  ```
#  although the exact numbers will be different. Check to make sure the data is shifted over one step for `y`.

# %% [markdown]
# ## Building the model
#
# Below is where you'll build the network. We'll break it up into parts so it's easier to reason about each bit. Then we can connect them up into the whole network.
#
# <img src="assets/charRNN.png" width=500px>
#
#
# ### Inputs
#
# First off we'll create our input placeholders. As usual we need placeholders for the training data and the targets. We'll also create a placeholder for dropout layers called `keep_prob`.

# %%
def build_inputs(batch_size, num_steps):
    ''' Define placeholders for inputs, targets, and dropout 
    
        Arguments
        ---------
        batch_size: Batch size, number of sequences per batch
        num_steps: Number of sequence steps in a batch
        
    '''
    # Declare placeholders we'll feed into the graph
    inputs = tf.placeholder(tf.int32, [batch_size, num_steps], name='inputs')
    targets = tf.placeholder(tf.int32, [batch_size, num_steps], name='targets')
    
    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    
    return inputs, targets, keep_prob

# %% [markdown]
# ### LSTM Cell
#
# Here we will create the LSTM cell we'll use in the hidden layer. We'll use this cell as a building block for the RNN. So we aren't actually defining the RNN here, just the type of cell we'll use in the hidden layer.
#
# We first create a basic LSTM cell with
#
# ```python
# lstm = tf.contrib.rnn.BasicLSTMCell(num_units)
# ```
#
# where `num_units` is the number of units in the hidden layers in the cell. Then we can add dropout by wrapping it with
#
# ```python
# tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
# ```
# You pass in a cell and it will automatically add dropout to the inputs or outputs. Finally, we can stack up the LSTM cells into layers with [`tf.contrib.rnn.MultiRNNCell`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/rnn/MultiRNNCell). With this, you pass in a list of cells and it will send the output of one cell into the next cell. For example,
#
# ```python
# tf.contrib.rnn.MultiRNNCell([cell]*num_layers)
# ```
#
# This might look a little weird if you know Python well because this will create a list of the same `cell` object. However, TensorFlow will create different weight matrices for all `cell` objects. Even though this is actually multiple LSTM cells stacked on each other, you can treat the multiple layers as one cell.
#
# We also need to create an initial cell state of all zeros. This can be done like so
#
# ```python
# initial_state = cell.zero_state(batch_size, tf.float32)
# ```
#
# Below, we implement the `build_lstm` function to create these LSTM cells and the initial state.

# %%
def make_cell(rnn_size):
    enc_cell = tf.contrib.rnn.LSTMCell(rnn_size, initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
    return enc_cell

# %%
def build_lstm(lstm_size, num_layers, batch_size, keep_prob):
    ''' Build LSTM cell.
    
        Arguments
        ---------
        keep_prob: Scalar tensor (tf.placeholder) for the dropout keep probability
        lstm_size: Size of the hidden layers in the LSTM cells
        num_layers: Number of LSTM layers
        batch_size: Batch size

    '''
    ### Build the LSTM Cell
    # Use a basic LSTM cell
    #lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
    
    # Add dropout to the cell
    #drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
    
    # Stack up multiple LSTM layers, for deep learning
    #cell = tf.contrib.rnn.MultiRNNCell([drop] * num_layers)
    
    cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.DropoutWrapper(make_cell(lstm_size), output_keep_prob=keep_prob) for _ in range(num_layers)])
    
    initial_state = cell.zero_state(batch_size, tf.float32)
    
    return cell, initial_state

# %% [markdown]
# ### RNN Output
#
# Here we'll create the output layer. We need to connect the output of the RNN cells to a full connected layer with a softmax output. The softmax output gives us a probability distribution we can use to predict the next character.
#
# If our input has batch size $N$, number of steps $M$, and the hidden layer has $L$ hidden units, then the output is a 3D tensor with size $N \times M \times L$. The output of each LSTM cell has size $L$, we have $M$ of them, one for each sequence step, and we have $N$ sequences. So the total size is $N \times M \times L$.
#
# We are using the same fully connected layer, the same weights, for each of the outputs. Then, to make things easier, we should reshape the outputs into a 2D tensor with shape $(M * N) \times L$. That is, one row for each sequence and step, where the values of each row are the output from the LSTM cells.
#
# One we have the outputs reshaped, we can do the matrix multiplication with the weights. We need to wrap the weight and bias variables in a variable scope with `tf.variable_scope(scope_name)` because there are weights being created in the LSTM cells. TensorFlow will throw an error if the weights created here have the same names as the weights created in the LSTM cells, which they will be default. To avoid this, we wrap the variables in a variable scope so we can give them unique names.

# %%
def build_output(lstm_output, in_size, out_size):
    ''' Build a softmax layer, return the softmax output and logits.
    
        Arguments
        ---------
        
        x: Input tensor
        in_size: Size of the input tensor, for example, size of the LSTM cells
        out_size: Size of this softmax layer
    
    '''

    # Reshape output so it's a bunch of rows, one row for each step for each sequence.
    # That is, the shape should be batch_size*num_steps rows by lstm_size columns
    seq_output = tf.concat(lstm_output, axis=1)
    x = tf.reshape(seq_output, [-1, in_size])
    
    # Connect the RNN outputs to a softmax layer
    with tf.variable_scope('softmax'):
        softmax_w = tf.Variable(tf.truncated_normal((in_size, out_size), stddev=0.1))
        softmax_b = tf.Variable(tf.zeros(out_size))
    
    # Since output is a bunch of rows of RNN cell outputs, logits will be a bunch
    # of rows of logit outputs, one for each step and sequence
    logits = tf.matmul(x, softmax_w) + softmax_b
    
    # Use softmax to get the probabilities for predicted characters
    out = tf.nn.softmax(logits, name='predictions')
    
    return out, logits

# %% [markdown]
# ### Training loss
#
# Next up is the training loss. We get the logits and targets and calculate the softmax cross-entropy loss. First we need to one-hot encode the targets, we're getting them as encoded characters. Then, reshape the one-hot targets so it's a 2D tensor with size $(M*N) \times C$ where $C$ is the number of classes/characters we have. Remember that we reshaped the LSTM outputs and ran them through a fully connected layer with $C$ units. So our logits will also have size $(M*N) \times C$.
#
# Then we run the logits and targets through `tf.nn.softmax_cross_entropy_with_logits` and find the mean to get the loss.

# %%
def build_loss(logits, targets, lstm_size, num_classes):
    ''' Calculate the loss from the logits and the targets.
    
        Arguments
        ---------
        logits: Logits from final fully connected layer
        targets: Targets for supervised learning
        lstm_size: Number of LSTM hidden units
        num_classes: Number of classes in targets
        
    '''
    
    # One-hot encode targets and reshape to match logits, one row per batch_size per step
    y_one_hot = tf.one_hot(targets, num_classes)
    y_reshaped = tf.reshape(y_one_hot, logits.get_shape())
    
    # Softmax cross entropy loss
    loss = tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y_reshaped)
    loss = tf.reduce_mean(loss)
    return loss

# %% [markdown]
# ### Optimizer
#
# Here we build the optimizer. Normal RNNs have have issues gradients exploding and disappearing. LSTMs fix the disappearance problem, but the gradients can still grow without bound. To fix this, we can clip the gradients above some threshold. That is, if a gradient is larger than that threshold, we set it to the threshold. This will ensure the gradients never grow overly large. Then we use an AdamOptimizer for the learning step.

# %%
def build_optimizer(loss, learning_rate, grad_clip):
    ''' Build optmizer for training, using gradient clipping.
    
        Arguments:
        loss: Network loss
        learning_rate: Learning rate for optimizer
    
    '''
    
    # Optimizer for training, using gradient clipping to control exploding gradients
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
    train_op = tf.train.AdamOptimizer(learning_rate)
    optimizer = train_op.apply_gradients(zip(grads, tvars))
    
    return optimizer

# %% [markdown]
# ### Build the network
#
# Now we can put all the pieces together and build a class for the network. To actually run data through the LSTM cells, we will use [`tf.nn.dynamic_rnn`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/nn/dynamic_rnn). This function will pass the hidden and cell states across LSTM cells appropriately for us. It returns the outputs for each LSTM cell at each step for each sequence in the mini-batch. It also gives us the final LSTM state. We want to save this state as `final_state` so we can pass it to the first LSTM cell in the the next mini-batch run. For `tf.nn.dynamic_rnn`, we pass in the cell and initial state we get from `build_lstm`, as well as our input sequences. Also, we need to one-hot encode the inputs before going into the RNN.

# %%
class CharRNN:
    
    def __init__(self, num_classes, batch_size=64, num_steps=50, 
                       lstm_size=128, num_layers=2, learning_rate=0.001, 
                       grad_clip=5, sampling=False):
    
        # When we're using this network for sampling later, we'll be passing in
        # one character at a time, so providing an option for that
        if sampling == True:
            batch_size, num_steps = 1, 1
        else:
            batch_size, num_steps = batch_size, num_steps

        tf.reset_default_graph()
        
        # Build the input placeholder tensors
        self.inputs, self.targets, self.keep_prob = build_inputs(batch_size, num_steps)

        # Build the LSTM cell
        cell, self.initial_state = build_lstm(lstm_size, num_layers, batch_size, self.keep_prob)

        ### Run the data through the RNN layers
        # First, one-hot encode the input tokens
        x_one_hot = tf.one_hot(self.inputs, num_classes)
        
        # Run each sequence step through the RNN and collect the outputs
        outputs, state = tf.nn.dynamic_rnn(cell, x_one_hot, initial_state=self.initial_state)
        self.final_state = state
        
        # Get softmax predictions and logits
        self.prediction, self.logits = build_output(outputs, lstm_size, num_classes)
        
        # Loss and optimizer (with gradient clipping)
        self.loss = build_loss(self.logits, self.targets, lstm_size, num_classes)
        self.optimizer = build_optimizer(self.loss, learning_rate, grad_clip)

# %% [markdown]
# ## Hyperparameters
#
# Here I'm defining the hyperparameters for the network.
#
# * `batch_size` - Number of sequences running through the network in one pass.
# * `num_steps` - Number of characters in the sequence the network is trained on. Larger is better typically, the network will learn more long range dependencies. But it takes longer to train. 100 is typically a good number here.
# * `lstm_size` - The number of units in the hidden layers.
# * `num_layers` - Number of hidden LSTM layers to use
# * `learning_rate` - Learning rate for training
# * `keep_prob` - The dropout keep probability when training. If you're network is overfitting, try decreasing this.
#
# Here's some good advice from Andrej Karpathy on training the network. I'm going to copy it in here for your benefit, but also link to [where it originally came from](https://github.com/karpathy/char-rnn#tips-and-tricks).
#
# > ## Tips and Tricks
#
# >### Monitoring Validation Loss vs. Training Loss
# >If you're somewhat new to Machine Learning or Neural Networks it can take a bit of expertise to get good models. The most important quantity to keep track of is the difference between your training loss (printed during training) and the validation loss (printed once in a while when the RNN is run on the validation data (by default every 1000 iterations)). In particular:
#
# > - If your training loss is much lower than validation loss then this means the network might be **overfitting**. Solutions to this are to decrease your network size, or to increase dropout. For example you could try dropout of 0.5 and so on.
# > - If your training/validation loss are about equal then your model is **underfitting**. Increase the size of your model (either number of layers or the raw number of neurons per layer)
#
# > ### Approximate number of parameters
#
# > The two most important parameters that control the model are `lstm_size` and `num_layers`. I would advise that you always use `num_layers` of either 2/3. The `lstm_size` can be adjusted based on how much data you have. The two important quantities to keep track of here are:
#
# > - The number of parameters in your model. This is printed when you start training.
# > - The size of your dataset. 1MB file is approximately 1 million characters.
#
# >These two should be about the same order of magnitude. It's a little tricky to tell. Here are some examples:
#
# > - I have a 100MB dataset and I'm using the default parameter settings (which currently print 150K parameters). My data size is significantly larger (100 mil >> 0.15 mil), so I expect to heavily underfit. I am thinking I can comfortably afford to make `lstm_size` larger.
# > - I have a 10MB dataset and running a 10 million parameter model. I'm slightly nervous and I'm carefully monitoring my validation loss. If it's larger than my training loss then I may want to try to increase dropout a bit and see if that helps the validation loss.
#
# > ### Best models strategy
#
# >The winning strategy to obtaining very good models (if you have the compute time) is to always err on making the network larger (as large as you're willing to wait for it to compute) and then try different dropout values (between 0,1). Whatever model has the best validation performance (the loss, written in the checkpoint filename, low is good) is the one you should use in the end.
#
# >It is very common in deep learning to run many different models with many different hyperparameter settings, and in the end take whatever checkpoint gave the best validation performance.
#
# >By the way, the size of your training and validation splits are also parameters. Make sure you have a decent amount of data in your validation set or otherwise the validation performance will be noisy and not very informative.

# %%
batch_size = 100        # Sequences per batch
num_steps = 100         # Number of sequence steps per batch
lstm_size = 256         # Size of hidden layers in LSTMs
num_layers = 2          # Number of LSTM layers
learning_rate = 0.001   # Learning rate
keep_prob = 0.5         # Dropout keep probability

# %% [markdown]
# ## Time for training
#
# This is typical training code, passing inputs and targets into the network, then running the optimizer. Here we also get back the final LSTM state for the mini-batch. Then, we pass that state back into the network so the next batch can continue the state from the previous batch. And every so often (set by `save_every_n`) I save a checkpoint.
#
# Here I'm saving checkpoints with the format
#
# `i{iteration number}_l{# hidden layer units}.ckpt`

# %%
epochs = 20
# Save every N iterations
save_every_n = 200

model = CharRNN(len(vocab), batch_size=batch_size, num_steps=num_steps,
                lstm_size=lstm_size, num_layers=num_layers, 
                learning_rate=learning_rate)

saver = tf.train.Saver(max_to_keep=100)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    file_writer = tf.summary.FileWriter('./logs/1', sess.graph)
    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/______.ckpt')
    counter = 0
    for e in range(epochs):
        # Train network
        new_state = sess.run(model.initial_state)
        loss = 0
        for x, y in get_batches(encoded, batch_size, num_steps):
            counter += 1
            start = time.time()
            feed = {model.inputs: x,
                    model.targets: y,
                    model.keep_prob: keep_prob,
                    model.initial_state: new_state}
            batch_loss, new_state, _ = sess.run([model.loss, 
                                                 model.final_state, 
                                                 model.optimizer], 
                                                 feed_dict=feed)
            
            end = time.time()
            print('Epoch: {}/{}... '.format(e+1, epochs),
                  'Training Step: {}... '.format(counter),
                  'Training loss: {:.4f}... '.format(batch_loss),
                  '{:.4f} sec/batch'.format((end-start)))
        
            if (counter % save_every_n == 0):
                saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
    
    saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
# Out:
# Epoch: 1/20...  Training Step: 1...  Training loss: 4.4288...  0.9803 sec/batch
# Epoch: 1/20...  Training Step: 2...  Training loss: 4.3038...  0.9970 sec/batch
# Epoch: 1/20...  Training Step: 3...  Training loss: 4.0494...  0.9812 sec/batch
# Epoch: 1/20...  Training Step: 4...  Training loss: 3.7985...  0.9725 sec/batch
# Epoch: 1/20...  Training Step: 5...  Training loss: 3.6541...  1.0013 sec/batch
# Epoch: 1/20...  Training Step: 6...  Training loss: 3.5654...  0.9798 sec/batch
# Epoch: 1/20...  Training Step: 7...  Training loss: 3.4783...  0.9817 sec/batch
# Epoch: 1/20...  Training Step: 8...  Training loss: 3.4384...  1.0218 sec/batch
# Epoch: 1/20...  Training Step: 9...  Training loss: 3.3994...  0.9969 sec/batch
# Epoch: 1/20...  Training Step: 10...  Training loss: 3.3839...  0.9938 sec/batch
# Epoch: 1/20...  Training Step: 11...  Training loss: 3.3466...  1.1078 sec/batch
# Epoch: 1/20...  Training Step: 12...  Training loss: 3.3360...  1.1693 sec/batch
# Epoch: 1/20...  Training Step: 13...  Training loss: 3.3175...  1.2421 sec/batch
# Epoch: 1/20...  Training Step: 14...  Training loss: 3.3193...  1.2400 sec/batch
# Epoch: 1/20...  Training Step: 15...  Training loss: 3.3014...  1.2969 sec/batch
# Epoch: 1/20...  Training Step: 16...  Training loss: 3.2882...  1.2854 sec/batch
# Epoch: 1/20...  Training Step: 17...  Training loss: 3.2702...  1.1744 sec/batch
# Epoch: 1/20...  Training Step: 18...  Training loss: 3.2945...  1.2437 sec/batch
# Epoch: 1/20...  Training Step: 19...  Training loss: 3.2727...  1.2797 sec/batch
# Epoch: 1/20...  Training Step: 20...  Training loss: 3.2375...  1.2083 sec/batch
# Epoch: 1/20...  Training Step: 21...  Training loss: 3.2554...  1.2492 sec/batch
# Epoch: 1/20...  Training Step: 22...  Training loss: 3.2411...  1.1946 sec/batch
# Epoch: 1/20...  Training Step: 23...  Training loss: 3.2319...  1.0646 sec/batch
# Epoch: 1/20...  Training Step: 24...  Training loss: 3.2297...  1.1600 sec/batch
# Epoch: 1/20...  Training Step: 25...  Training loss: 3.2292...  1.2925 sec/batch
# Epoch: 1/20...  Training Step: 26...  Training loss: 3.2436...  1.2470 sec/batch
# Epoch: 1/20...  Training Step: 27...  Training loss: 3.2451...  1.2323 sec/batch
# Epoch: 1/20...  Training Step: 28...  Training loss: 3.2138...  1.2433 sec/batch
# Epoch: 1/20...  Training Step: 29...  Training loss: 3.2129...  1.2556 sec/batch
# Epoch: 1/20...  Training Step: 30...  Training loss: 3.2179...  1.2312 sec/batch
# Epoch: 1/20...  Training Step: 31...  Training loss: 3.2403...  1.2474 sec/batch
# Epoch: 1/20...  Training Step: 32...  Training loss: 3.2060...  1.2148 sec/batch
# Epoch: 1/20...  Training Step: 33...  Training loss: 3.1959...  1.2232 sec/batch
# Epoch: 1/20...  Training Step: 34...  Training loss: 3.2073...  1.2620 sec/batch
# Epoch: 1/20...  Training Step: 35...  Training loss: 3.1917...  1.2257 sec/batch
# Epoch: 1/20...  Training Step: 36...  Training loss: 3.2072...  1.1472 sec/batch
# Epoch: 1/20...  Training Step: 37...  Training loss: 3.1778...  1.1240 sec/batch
# Epoch: 1/20...  Training Step: 38...  Training loss: 3.1766...  1.1939 sec/batch
# Epoch: 1/20...  Training Step: 39...  Training loss: 3.1706...  1.2121 sec/batch
# Epoch: 1/20...  Training Step: 40...  Training loss: 3.1812...  1.0024 sec/batch
# Epoch: 1/20...  Training Step: 41...  Training loss: 3.1672...  1.0930 sec/batch
# Epoch: 1/20...  Training Step: 42...  Training loss: 3.1802...  1.1034 sec/batch
# Epoch: 1/20...  Training Step: 43...  Training loss: 3.1674...  1.1285 sec/batch
# Epoch: 1/20...  Training Step: 44...  Training loss: 3.1649...  1.1554 sec/batch
# Epoch: 1/20...  Training Step: 45...  Training loss: 3.1566...  1.2810 sec/batch
# Epoch: 1/20...  Training Step: 46...  Training loss: 3.1792...  1.2652 sec/batch
# Epoch: 1/20...  Training Step: 47...  Training loss: 3.1796...  1.2710 sec/batch
# Epoch: 1/20...  Training Step: 48...  Training loss: 3.1836...  1.2440 sec/batch
# Epoch: 1/20...  Training Step: 49...  Training loss: 3.1783...  1.3187 sec/batch
# Epoch: 1/20...  Training Step: 50...  Training loss: 3.1801...  1.2294 sec/batch
# Epoch: 1/20...  Training Step: 51...  Training loss: 3.1681...  1.2145 sec/batch
# Epoch: 1/20...  Training Step: 52...  Training loss: 3.1601...  1.0715 sec/batch
# Epoch: 1/20...  Training Step: 53...  Training loss: 3.1679...  1.0411 sec/batch
# Epoch: 1/20...  Training Step: 54...  Training loss: 3.1592...  1.1169 sec/batch
# Epoch: 1/20...  Training Step: 55...  Training loss: 3.1659...  1.0170 sec/batch
# Epoch: 1/20...  Training Step: 56...  Training loss: 3.1451...  1.0277 sec/batch
# Epoch: 1/20...  Training Step: 57...  Training loss: 3.1559...  1.0382 sec/batch
# Epoch: 1/20...  Training Step: 58...  Training loss: 3.1645...  1.0775 sec/batch
# Epoch: 1/20...  Training Step: 59...  Training loss: 3.1490...  1.2239 sec/batch
# Epoch: 1/20...  Training Step: 60...  Training loss: 3.1568...  1.1095 sec/batch
# Epoch: 1/20...  Training Step: 61...  Training loss: 3.1592...  1.0800 sec/batch
# Epoch: 1/20...  Training Step: 62...  Training loss: 3.1785...  1.2441 sec/batch
# Epoch: 1/20...  Training Step: 63...  Training loss: 3.1772...  1.0846 sec/batch
# Epoch: 1/20...  Training Step: 64...  Training loss: 3.1358...  1.0181 sec/batch
# Epoch: 1/20...  Training Step: 65...  Training loss: 3.1332...  1.0344 sec/batch
# Epoch: 1/20...  Training Step: 66...  Training loss: 3.1708...  1.0099 sec/batch
# Epoch: 1/20...  Training Step: 67...  Training loss: 3.1640...  1.0060 sec/batch
# Epoch: 1/20...  Training Step: 68...  Training loss: 3.1139...  0.9822 sec/batch
# Epoch: 1/20...  Training Step: 69...  Training loss: 3.1327...  0.9844 sec/batch
# Epoch: 1/20...  Training Step: 70...  Training loss: 3.1557...  1.0503 sec/batch
# Epoch: 1/20...  Training Step: 71...  Training loss: 3.1457...  0.9791 sec/batch
# Epoch: 1/20...  Training Step: 72...  Training loss: 3.1675...  0.9762 sec/batch
# Epoch: 1/20...  Training Step: 73...  Training loss: 3.1377...  0.9795 sec/batch
# Epoch: 1/20...  Training Step: 74...  Training loss: 3.1448...  0.9611 sec/batch
# Epoch: 1/20...  Training Step: 75...  Training loss: 3.1487...  0.9530 sec/batch
# Epoch: 1/20...  Training Step: 76...  Training loss: 3.1527...  0.9636 sec/batch
# Epoch: 1/20...  Training Step: 77...  Training loss: 3.1496...  0.9633 sec/batch
# Epoch: 1/20...  Training Step: 78...  Training loss: 3.1438...  0.9834 sec/batch
# Epoch: 1/20...  Training Step: 79...  Training loss: 3.1343...  0.9737 sec/batch
# Epoch: 1/20...  Training Step: 80...  Training loss: 3.1226...  1.0485 sec/batch
# Epoch: 1/20...  Training Step: 81...  Training loss: 3.1311...  1.0809 sec/batch
# Epoch: 1/20...  Training Step: 82...  Training loss: 3.1447...  1.0331 sec/batch
# Epoch: 1/20...  Training Step: 83...  Training loss: 3.1467...  1.0845 sec/batch
# Epoch: 1/20...  Training Step: 84...  Training loss: 3.1346...  1.1116 sec/batch
# Epoch: 1/20...  Training Step: 85...  Training loss: 3.1075...  1.1242 sec/batch
# Epoch: 1/20...  Training Step: 86...  Training loss: 3.1222...  1.0365 sec/batch
# Epoch: 1/20...  Training Step: 87...  Training loss: 3.1113...  1.0195 sec/batch
# Epoch: 1/20...  Training Step: 88...  Training loss: 3.1135...  1.0200 sec/batch
# Epoch: 1/20...  Training Step: 89...  Training loss: 3.1296...  1.0159 sec/batch
# Epoch: 1/20...  Training Step: 90...  Training loss: 3.1209...  1.0521 sec/batch
# Epoch: 1/20...  Training Step: 91...  Training loss: 3.1248...  1.0224 sec/batch
# Epoch: 1/20...  Training Step: 92...  Training loss: 3.1116...  1.0028 sec/batch
# Epoch: 1/20...  Training Step: 93...  Training loss: 3.1167...  1.0274 sec/batch
# Epoch: 1/20...  Training Step: 94...  Training loss: 3.1131...  1.0555 sec/batch
# Epoch: 1/20...  Training Step: 95...  Training loss: 3.1005...  1.0963 sec/batch
# Epoch: 1/20...  Training Step: 96...  Training loss: 3.1025...  1.2496 sec/batch
# Epoch: 1/20...  Training Step: 97...  Training loss: 3.1078...  1.1514 sec/batch
# Epoch: 1/20...  Training Step: 98...  Training loss: 3.0999...  1.0657 sec/batch
# Epoch: 1/20...  Training Step: 99...  Training loss: 3.1018...  0.9882 sec/batch
# Epoch: 1/20...  Training Step: 100...  Training loss: 3.0880...  0.9894 sec/batch
# Epoch: 1/20...  Training Step: 101...  Training loss: 3.0971...  0.9948 sec/batch
# Epoch: 1/20...  Training Step: 102...  Training loss: 3.0863...  0.9958 sec/batch
# Epoch: 1/20...  Training Step: 103...  Training loss: 3.0856...  1.1941 sec/batch
# Epoch: 1/20...  Training Step: 104...  Training loss: 3.0745...  1.2044 sec/batch
# Epoch: 1/20...  Training Step: 105...  Training loss: 3.0680...  1.0331 sec/batch
# Epoch: 1/20...  Training Step: 106...  Training loss: 3.0700...  1.0308 sec/batch
# Epoch: 1/20...  Training Step: 107...  Training loss: 3.0427...  1.0203 sec/batch
# Epoch: 1/20...  Training Step: 108...  Training loss: 3.0556...  1.1740 sec/batch
# Epoch: 1/20...  Training Step: 109...  Training loss: 3.0732...  1.2036 sec/batch
# Epoch: 1/20...  Training Step: 110...  Training loss: 3.0164...  1.0724 sec/batch
# Epoch: 1/20...  Training Step: 111...  Training loss: 3.0451...  1.0006 sec/batch
# Epoch: 1/20...  Training Step: 112...  Training loss: 3.0363...  1.0778 sec/batch
# Epoch: 1/20...  Training Step: 113...  Training loss: 3.0256...  1.0503 sec/batch
# Epoch: 1/20...  Training Step: 114...  Training loss: 3.0077...  0.9938 sec/batch
# Epoch: 1/20...  Training Step: 115...  Training loss: 3.0074...  0.9798 sec/batch
# Epoch: 1/20...  Training Step: 116...  Training loss: 3.0009...  0.9897 sec/batch
# Epoch: 1/20...  Training Step: 117...  Training loss: 2.9904...  1.0139 sec/batch
# Epoch: 1/20...  Training Step: 118...  Training loss: 3.0088...  1.0073 sec/batch
# Epoch: 1/20...  Training Step: 119...  Training loss: 3.0014...  0.9840 sec/batch
# Epoch: 1/20...  Training Step: 120...  Training loss: 2.9761...  1.0069 sec/batch
# Epoch: 1/20...  Training Step: 121...  Training loss: 2.9887...  0.9901 sec/batch
# Epoch: 1/20...  Training Step: 122...  Training loss: 2.9717...  0.9753 sec/batch
# Epoch: 1/20...  Training Step: 123...  Training loss: 2.9499...  0.9950 sec/batch
# Epoch: 1/20...  Training Step: 124...  Training loss: 2.9590...  0.9851 sec/batch
# Epoch: 1/20...  Training Step: 125...  Training loss: 2.9353...  1.0038 sec/batch
# Epoch: 1/20...  Training Step: 126...  Training loss: 2.8997...  1.0045 sec/batch
# Epoch: 1/20...  Training Step: 127...  Training loss: 2.9233...  1.0054 sec/batch
# Epoch: 1/20...  Training Step: 128...  Training loss: 2.9443...  0.9967 sec/batch
# Epoch: 1/20...  Training Step: 129...  Training loss: 2.9281...  0.9835 sec/batch
# Epoch: 1/20...  Training Step: 130...  Training loss: 2.9043...  0.9802 sec/batch
# Epoch: 1/20...  Training Step: 131...  Training loss: 2.9093...  0.9932 sec/batch
# Epoch: 1/20...  Training Step: 132...  Training loss: 2.8778...  0.9792 sec/batch
# Epoch: 1/20...  Training Step: 133...  Training loss: 2.8911...  1.0002 sec/batch
# Epoch: 1/20...  Training Step: 134...  Training loss: 2.8676...  1.0055 sec/batch
# Epoch: 1/20...  Training Step: 135...  Training loss: 2.8355...  0.9828 sec/batch
# Epoch: 1/20...  Training Step: 136...  Training loss: 2.8259...  1.0061 sec/batch
# Epoch: 1/20...  Training Step: 137...  Training loss: 2.8425...  0.9893 sec/batch
# Epoch: 1/20...  Training Step: 138...  Training loss: 2.8177...  1.0127 sec/batch
# Epoch: 1/20...  Training Step: 139...  Training loss: 2.8401...  0.9856 sec/batch
# Epoch: 1/20...  Training Step: 140...  Training loss: 2.8270...  0.9936 sec/batch
# Epoch: 1/20...  Training Step: 141...  Training loss: 2.8293...  0.9757 sec/batch
# Epoch: 1/20...  Training Step: 142...  Training loss: 2.7811...  1.0022 sec/batch
# Epoch: 1/20...  Training Step: 143...  Training loss: 2.7992...  1.0091 sec/batch
# Epoch: 1/20...  Training Step: 144...  Training loss: 2.7809...  0.9998 sec/batch
# Epoch: 1/20...  Training Step: 145...  Training loss: 2.7856...  1.0059 sec/batch
# Epoch: 1/20...  Training Step: 146...  Training loss: 2.7889...  0.9959 sec/batch
# Epoch: 1/20...  Training Step: 147...  Training loss: 2.7730...  0.9954 sec/batch
# Epoch: 1/20...  Training Step: 148...  Training loss: 2.7901...  0.9909 sec/batch
# Epoch: 1/20...  Training Step: 149...  Training loss: 2.7353...  1.0577 sec/batch
# Epoch: 1/20...  Training Step: 150...  Training loss: 2.7374...  1.0312 sec/batch
# Epoch: 1/20...  Training Step: 151...  Training loss: 2.7823...  1.0081 sec/batch
# Epoch: 1/20...  Training Step: 152...  Training loss: 2.7709...  1.1155 sec/batch
# Epoch: 1/20...  Training Step: 153...  Training loss: 2.7279...  0.9809 sec/batch
# Epoch: 1/20...  Training Step: 154...  Training loss: 2.7283...  1.0059 sec/batch
# Epoch: 1/20...  Training Step: 155...  Training loss: 2.7003...  0.9973 sec/batch
# Epoch: 1/20...  Training Step: 156...  Training loss: 2.6947...  1.0013 sec/batch
# Epoch: 1/20...  Training Step: 157...  Training loss: 2.6832...  1.0050 sec/batch
# Epoch: 1/20...  Training Step: 158...  Training loss: 2.6830...  0.9930 sec/batch
# Epoch: 1/20...  Training Step: 159...  Training loss: 2.6528...  0.9932 sec/batch
# Epoch: 1/20...  Training Step: 160...  Training loss: 2.6802...  0.9714 sec/batch
# Epoch: 1/20...  Training Step: 161...  Training loss: 2.6761...  0.9838 sec/batch
# Epoch: 1/20...  Training Step: 162...  Training loss: 2.6330...  0.9801 sec/batch
# Epoch: 1/20...  Training Step: 163...  Training loss: 2.6344...  0.9804 sec/batch
# Epoch: 1/20...  Training Step: 164...  Training loss: 2.6549...  0.9944 sec/batch
# Epoch: 1/20...  Training Step: 165...  Training loss: 2.6483...  1.0144 sec/batch
# Epoch: 1/20...  Training Step: 166...  Training loss: 2.6414...  1.0039 sec/batch
# Epoch: 1/20...  Training Step: 167...  Training loss: 2.6511...  1.0079 sec/batch
# Epoch: 1/20...  Training Step: 168...  Training loss: 2.6278...  0.9961 sec/batch
# Epoch: 1/20...  Training Step: 169...  Training loss: 2.6353...  1.0103 sec/batch
# Epoch: 1/20...  Training Step: 170...  Training loss: 2.6063...  1.0045 sec/batch
# Epoch: 1/20...  Training Step: 171...  Training loss: 2.6244...  1.0134 sec/batch
# Epoch: 1/20...  Training Step: 172...  Training loss: 2.6447...  0.9914 sec/batch
# Epoch: 1/20...  Training Step: 173...  Training loss: 2.6563...  1.0059 sec/batch
# Epoch: 1/20...  Training Step: 174...  Training loss: 2.6595...  0.9842 sec/batch
# Epoch: 1/20...  Training Step: 175...  Training loss: 2.6352...  0.9942 sec/batch
# Epoch: 1/20...  Training Step: 176...  Training loss: 2.6843...  0.9995 sec/batch
# Epoch: 1/20...  Training Step: 177...  Training loss: 2.6767...  0.9905 sec/batch
# Epoch: 1/20...  Training Step: 178...  Training loss: 2.6468...  0.9960 sec/batch
# Epoch: 1/20...  Training Step: 179...  Training loss: 2.6329...  0.9868 sec/batch
# Epoch: 1/20...  Training Step: 180...  Training loss: 2.6209...  1.0065 sec/batch
# Epoch: 1/20...  Training Step: 181...  Training loss: 2.6331...  1.0230 sec/batch
# Epoch: 1/20...  Training Step: 182...  Training loss: 2.6300...  0.9633 sec/batch
# Epoch: 1/20...  Training Step: 183...  Training loss: 2.5965...  1.0190 sec/batch
# Epoch: 1/20...  Training Step: 184...  Training loss: 2.6128...  1.0024 sec/batch
# Epoch: 1/20...  Training Step: 185...  Training loss: 2.5915...  0.9764 sec/batch
# Epoch: 1/20...  Training Step: 186...  Training loss: 2.5828...  0.9965 sec/batch
# Epoch: 1/20...  Training Step: 187...  Training loss: 2.5732...  0.9895 sec/batch
# Epoch: 1/20...  Training Step: 188...  Training loss: 2.5639...  1.0041 sec/batch
# Epoch: 1/20...  Training Step: 189...  Training loss: 2.5695...  0.9968 sec/batch
# Epoch: 1/20...  Training Step: 190...  Training loss: 2.5740...  1.0032 sec/batch
# Epoch: 1/20...  Training Step: 191...  Training loss: 2.5674...  1.0170 sec/batch
# Epoch: 1/20...  Training Step: 192...  Training loss: 2.5336...  0.9870 sec/batch
# Epoch: 1/20...  Training Step: 193...  Training loss: 2.5549...  1.0011 sec/batch
# Epoch: 1/20...  Training Step: 194...  Training loss: 2.5422...  0.9784 sec/batch
# Epoch: 1/20...  Training Step: 195...  Training loss: 2.5397...  0.9729 sec/batch
# Epoch: 1/20...  Training Step: 196...  Training loss: 2.5373...  0.9887 sec/batch
# Epoch: 1/20...  Training Step: 197...  Training loss: 2.5360...  0.9881 sec/batch
# Epoch: 1/20...  Training Step: 198...  Training loss: 2.5268...  0.9951 sec/batch
# Epoch: 2/20...  Training Step: 199...  Training loss: 2.6285...  0.9929 sec/batch
# Epoch: 2/20...  Training Step: 200...  Training loss: 2.5051...  1.0245 sec/batch
# Epoch: 2/20...  Training Step: 201...  Training loss: 2.5156...  1.0184 sec/batch
# Epoch: 2/20...  Training Step: 202...  Training loss: 2.5199...  1.0178 sec/batch
# Epoch: 2/20...  Training Step: 203...  Training loss: 2.5263...  1.0103 sec/batch
# Epoch: 2/20...  Training Step: 204...  Training loss: 2.5136...  0.9887 sec/batch
# Epoch: 2/20...  Training Step: 205...  Training loss: 2.5220...  1.0000 sec/batch
# Epoch: 2/20...  Training Step: 206...  Training loss: 2.5209...  1.0085 sec/batch
# Epoch: 2/20...  Training Step: 207...  Training loss: 2.5265...  1.0132 sec/batch
# Epoch: 2/20...  Training Step: 208...  Training loss: 2.4943...  0.9983 sec/batch
# Epoch: 2/20...  Training Step: 209...  Training loss: 2.5074...  1.0685 sec/batch
# Epoch: 2/20...  Training Step: 210...  Training loss: 2.5129...  1.0037 sec/batch
# Epoch: 2/20...  Training Step: 211...  Training loss: 2.4957...  1.0361 sec/batch
# Epoch: 2/20...  Training Step: 212...  Training loss: 2.5429...  0.9938 sec/batch
# Epoch: 2/20...  Training Step: 213...  Training loss: 2.5077...  1.0089 sec/batch
# Epoch: 2/20...  Training Step: 214...  Training loss: 2.5022...  0.9957 sec/batch
# Epoch: 2/20...  Training Step: 215...  Training loss: 2.5011...  0.9749 sec/batch
# Epoch: 2/20...  Training Step: 216...  Training loss: 2.5328...  0.9968 sec/batch
# Epoch: 2/20...  Training Step: 217...  Training loss: 2.4980...  0.9895 sec/batch
# Epoch: 2/20...  Training Step: 218...  Training loss: 2.4728...  0.9959 sec/batch
# Epoch: 2/20...  Training Step: 219...  Training loss: 2.4822...  1.0043 sec/batch
# Epoch: 2/20...  Training Step: 220...  Training loss: 2.5093...  0.9885 sec/batch
# Epoch: 2/20...  Training Step: 221...  Training loss: 2.4947...  0.9884 sec/batch
# Epoch: 2/20...  Training Step: 222...  Training loss: 2.4750...  1.0260 sec/batch
# Epoch: 2/20...  Training Step: 223...  Training loss: 2.4663...  1.0015 sec/batch
# Epoch: 2/20...  Training Step: 224...  Training loss: 2.4740...  0.9763 sec/batch
# Epoch: 2/20...  Training Step: 225...  Training loss: 2.4659...  0.9818 sec/batch
# Epoch: 2/20...  Training Step: 226...  Training loss: 2.4758...  0.9941 sec/batch
# Epoch: 2/20...  Training Step: 227...  Training loss: 2.4882...  1.0023 sec/batch
# Epoch: 2/20...  Training Step: 228...  Training loss: 2.4784...  0.9752 sec/batch
# Epoch: 2/20...  Training Step: 229...  Training loss: 2.4893...  0.9764 sec/batch
# Epoch: 2/20...  Training Step: 230...  Training loss: 2.4646...  1.0024 sec/batch
# Epoch: 2/20...  Training Step: 231...  Training loss: 2.4433...  1.0045 sec/batch
# Epoch: 2/20...  Training Step: 232...  Training loss: 2.4793...  1.0055 sec/batch
# Epoch: 2/20...  Training Step: 233...  Training loss: 2.4429...  0.9985 sec/batch
# Epoch: 2/20...  Training Step: 234...  Training loss: 2.4627...  0.9935 sec/batch
# Epoch: 2/20...  Training Step: 235...  Training loss: 2.4499...  1.0057 sec/batch
# Epoch: 2/20...  Training Step: 236...  Training loss: 2.4254...  0.9738 sec/batch
# Epoch: 2/20...  Training Step: 237...  Training loss: 2.4347...  0.9954 sec/batch
# Epoch: 2/20...  Training Step: 238...  Training loss: 2.4364...  1.0173 sec/batch
# Epoch: 2/20...  Training Step: 239...  Training loss: 2.4245...  0.9968 sec/batch
# Epoch: 2/20...  Training Step: 240...  Training loss: 2.4368...  1.0032 sec/batch
# Epoch: 2/20...  Training Step: 241...  Training loss: 2.4262...  1.0150 sec/batch
# Epoch: 2/20...  Training Step: 242...  Training loss: 2.4265...  0.9797 sec/batch
# Epoch: 2/20...  Training Step: 243...  Training loss: 2.4205...  0.9847 sec/batch
# Epoch: 2/20...  Training Step: 244...  Training loss: 2.3868...  0.9976 sec/batch
# Epoch: 2/20...  Training Step: 245...  Training loss: 2.4390...  0.9937 sec/batch
# Epoch: 2/20...  Training Step: 246...  Training loss: 2.4191...  1.0231 sec/batch
# Epoch: 2/20...  Training Step: 247...  Training loss: 2.4270...  1.0213 sec/batch
# Epoch: 2/20...  Training Step: 248...  Training loss: 2.4453...  1.0024 sec/batch
# Epoch: 2/20...  Training Step: 249...  Training loss: 2.3986...  0.9895 sec/batch
# Epoch: 2/20...  Training Step: 250...  Training loss: 2.4258...  0.9780 sec/batch
# Epoch: 2/20...  Training Step: 251...  Training loss: 2.4153...  0.9905 sec/batch
# Epoch: 2/20...  Training Step: 252...  Training loss: 2.4111...  0.9956 sec/batch
# Epoch: 2/20...  Training Step: 253...  Training loss: 2.4006...  0.9993 sec/batch
# Epoch: 2/20...  Training Step: 254...  Training loss: 2.4172...  1.0096 sec/batch
# Epoch: 2/20...  Training Step: 255...  Training loss: 2.4124...  0.9855 sec/batch
# Epoch: 2/20...  Training Step: 256...  Training loss: 2.3991...  1.0288 sec/batch
# Epoch: 2/20...  Training Step: 257...  Training loss: 2.4001...  0.9927 sec/batch
# Epoch: 2/20...  Training Step: 258...  Training loss: 2.4214...  1.0185 sec/batch
# Epoch: 2/20...  Training Step: 259...  Training loss: 2.4146...  1.0025 sec/batch
# Epoch: 2/20...  Training Step: 260...  Training loss: 2.4149...  1.0059 sec/batch
# Epoch: 2/20...  Training Step: 261...  Training loss: 2.4303...  0.9954 sec/batch
# Epoch: 2/20...  Training Step: 262...  Training loss: 2.4066...  0.9710 sec/batch
# Epoch: 2/20...  Training Step: 263...  Training loss: 2.3848...  0.9863 sec/batch
# Epoch: 2/20...  Training Step: 264...  Training loss: 2.4159...  0.9846 sec/batch
# Epoch: 2/20...  Training Step: 265...  Training loss: 2.4094...  1.0002 sec/batch
# Epoch: 2/20...  Training Step: 266...  Training loss: 2.3715...  0.9972 sec/batch
# Epoch: 2/20...  Training Step: 267...  Training loss: 2.3766...  1.0197 sec/batch
# Epoch: 2/20...  Training Step: 268...  Training loss: 2.3959...  0.9992 sec/batch
# Epoch: 2/20...  Training Step: 269...  Training loss: 2.4185...  1.0416 sec/batch
# Epoch: 2/20...  Training Step: 270...  Training loss: 2.4075...  0.9943 sec/batch
# Epoch: 2/20...  Training Step: 271...  Training loss: 2.4037...  0.9818 sec/batch
# Epoch: 2/20...  Training Step: 272...  Training loss: 2.3897...  0.9826 sec/batch
# Epoch: 2/20...  Training Step: 273...  Training loss: 2.3885...  0.9695 sec/batch
# Epoch: 2/20...  Training Step: 274...  Training loss: 2.4327...  1.0194 sec/batch
# Epoch: 2/20...  Training Step: 275...  Training loss: 2.3721...  1.0177 sec/batch
# Epoch: 2/20...  Training Step: 276...  Training loss: 2.4022...  0.9872 sec/batch
# Epoch: 2/20...  Training Step: 277...  Training loss: 2.3714...  0.9728 sec/batch
# Epoch: 2/20...  Training Step: 278...  Training loss: 2.3717...  0.9869 sec/batch
# Epoch: 2/20...  Training Step: 279...  Training loss: 2.3578...  0.9834 sec/batch
# Epoch: 2/20...  Training Step: 280...  Training loss: 2.3968...  0.9837 sec/batch
# Epoch: 2/20...  Training Step: 281...  Training loss: 2.3631...  0.9685 sec/batch
# Epoch: 2/20...  Training Step: 282...  Training loss: 2.3496...  1.1756 sec/batch
# Epoch: 2/20...  Training Step: 283...  Training loss: 2.3455...  1.1453 sec/batch
# Epoch: 2/20...  Training Step: 284...  Training loss: 2.3743...  1.3523 sec/batch
# Epoch: 2/20...  Training Step: 285...  Training loss: 2.3736...  1.3025 sec/batch
# Epoch: 2/20...  Training Step: 286...  Training loss: 2.3712...  1.1422 sec/batch
# Epoch: 2/20...  Training Step: 287...  Training loss: 2.3541...  1.1179 sec/batch
# Epoch: 2/20...  Training Step: 288...  Training loss: 2.3712...  1.1781 sec/batch
# Epoch: 2/20...  Training Step: 289...  Training loss: 2.3650...  1.0847 sec/batch
# Epoch: 2/20...  Training Step: 290...  Training loss: 2.3763...  1.0915 sec/batch
# Epoch: 2/20...  Training Step: 291...  Training loss: 2.3646...  1.1103 sec/batch
# Epoch: 2/20...  Training Step: 292...  Training loss: 2.3402...  1.1597 sec/batch
# Epoch: 2/20...  Training Step: 293...  Training loss: 2.3304...  1.2596 sec/batch
# Epoch: 2/20...  Training Step: 294...  Training loss: 2.3324...  1.3320 sec/batch
# Epoch: 2/20...  Training Step: 295...  Training loss: 2.3343...  1.2211 sec/batch
# Epoch: 2/20...  Training Step: 296...  Training loss: 2.3364...  1.1878 sec/batch
# Epoch: 2/20...  Training Step: 297...  Training loss: 2.3216...  1.1319 sec/batch
# Epoch: 2/20...  Training Step: 298...  Training loss: 2.3223...  1.1093 sec/batch
# Epoch: 2/20...  Training Step: 299...  Training loss: 2.3514...  1.0554 sec/batch
# Epoch: 2/20...  Training Step: 300...  Training loss: 2.3364...  1.1186 sec/batch
# Epoch: 2/20...  Training Step: 301...  Training loss: 2.3141...  1.0738 sec/batch
# Epoch: 2/20...  Training Step: 302...  Training loss: 2.3187...  1.0797 sec/batch
# Epoch: 2/20...  Training Step: 303...  Training loss: 2.3199...  1.0720 sec/batch
# Epoch: 2/20...  Training Step: 304...  Training loss: 2.3230...  1.0852 sec/batch
# Epoch: 2/20...  Training Step: 305...  Training loss: 2.3226...  1.0522 sec/batch
# Epoch: 2/20...  Training Step: 306...  Training loss: 2.3418...  1.0860 sec/batch
# Epoch: 2/20...  Training Step: 307...  Training loss: 2.3379...  1.0738 sec/batch
# Epoch: 2/20...  Training Step: 308...  Training loss: 2.3098...  1.0861 sec/batch
# Epoch: 2/20...  Training Step: 309...  Training loss: 2.3308...  1.0993 sec/batch
# Epoch: 2/20...  Training Step: 310...  Training loss: 2.3417...  1.0771 sec/batch
# Epoch: 2/20...  Training Step: 311...  Training loss: 2.3118...  1.0863 sec/batch
# Epoch: 2/20...  Training Step: 312...  Training loss: 2.3005...  1.0624 sec/batch
# Epoch: 2/20...  Training Step: 313...  Training loss: 2.3075...  1.1159 sec/batch
# Epoch: 2/20...  Training Step: 314...  Training loss: 2.2778...  1.0817 sec/batch
# Epoch: 2/20...  Training Step: 315...  Training loss: 2.3142...  1.1010 sec/batch
# Epoch: 2/20...  Training Step: 316...  Training loss: 2.3122...  1.0887 sec/batch
# Epoch: 2/20...  Training Step: 317...  Training loss: 2.3356...  1.0967 sec/batch
# Epoch: 2/20...  Training Step: 318...  Training loss: 2.3132...  1.0965 sec/batch
# Epoch: 2/20...  Training Step: 319...  Training loss: 2.3418...  1.0886 sec/batch
# Epoch: 2/20...  Training Step: 320...  Training loss: 2.3079...  1.0912 sec/batch
# Epoch: 2/20...  Training Step: 321...  Training loss: 2.2962...  1.0805 sec/batch
# Epoch: 2/20...  Training Step: 322...  Training loss: 2.3258...  1.0811 sec/batch
# Epoch: 2/20...  Training Step: 323...  Training loss: 2.3010...  1.1233 sec/batch
# Epoch: 2/20...  Training Step: 324...  Training loss: 2.2829...  1.1325 sec/batch
# Epoch: 2/20...  Training Step: 325...  Training loss: 2.3167...  1.0821 sec/batch
# Epoch: 2/20...  Training Step: 326...  Training loss: 2.3141...  1.0824 sec/batch
# Epoch: 2/20...  Training Step: 327...  Training loss: 2.3033...  1.0942 sec/batch
# Epoch: 2/20...  Training Step: 328...  Training loss: 2.3082...  1.0807 sec/batch
# Epoch: 2/20...  Training Step: 329...  Training loss: 2.2911...  1.0947 sec/batch
# Epoch: 2/20...  Training Step: 330...  Training loss: 2.2588...  1.3474 sec/batch
# Epoch: 2/20...  Training Step: 331...  Training loss: 2.3051...  1.2468 sec/batch
# Epoch: 2/20...  Training Step: 332...  Training loss: 2.3026...  1.6034 sec/batch
# Epoch: 2/20...  Training Step: 333...  Training loss: 2.2804...  1.5063 sec/batch
# Epoch: 2/20...  Training Step: 334...  Training loss: 2.2860...  1.2118 sec/batch
# Epoch: 2/20...  Training Step: 335...  Training loss: 2.2899...  1.4371 sec/batch
# Epoch: 2/20...  Training Step: 336...  Training loss: 2.2935...  1.5725 sec/batch
# Epoch: 2/20...  Training Step: 337...  Training loss: 2.3246...  1.3597 sec/batch
# Epoch: 2/20...  Training Step: 338...  Training loss: 2.2831...  1.4122 sec/batch
# Epoch: 2/20...  Training Step: 339...  Training loss: 2.2923...  1.2300 sec/batch
# Epoch: 2/20...  Training Step: 340...  Training loss: 2.2777...  1.2370 sec/batch
# Epoch: 2/20...  Training Step: 341...  Training loss: 2.2809...  1.2710 sec/batch
# Epoch: 2/20...  Training Step: 342...  Training loss: 2.2804...  1.2791 sec/batch
# Epoch: 2/20...  Training Step: 343...  Training loss: 2.2746...  1.2816 sec/batch
# Epoch: 2/20...  Training Step: 344...  Training loss: 2.2946...  1.2673 sec/batch
# Epoch: 2/20...  Training Step: 345...  Training loss: 2.2885...  1.0939 sec/batch
# Epoch: 2/20...  Training Step: 346...  Training loss: 2.3097...  1.1439 sec/batch
# Epoch: 2/20...  Training Step: 347...  Training loss: 2.2636...  1.1032 sec/batch
# Epoch: 2/20...  Training Step: 348...  Training loss: 2.2588...  1.0639 sec/batch
# Epoch: 2/20...  Training Step: 349...  Training loss: 2.2790...  1.0875 sec/batch
# Epoch: 2/20...  Training Step: 350...  Training loss: 2.3115...  1.0862 sec/batch
# Epoch: 2/20...  Training Step: 351...  Training loss: 2.2848...  1.0807 sec/batch
# Epoch: 2/20...  Training Step: 352...  Training loss: 2.2877...  1.0381 sec/batch
# Epoch: 2/20...  Training Step: 353...  Training loss: 2.2617...  1.1325 sec/batch
# Epoch: 2/20...  Training Step: 354...  Training loss: 2.2602...  1.0802 sec/batch
# Epoch: 2/20...  Training Step: 355...  Training loss: 2.2507...  1.1203 sec/batch
# Epoch: 2/20...  Training Step: 356...  Training loss: 2.2590...  1.0869 sec/batch
# Epoch: 2/20...  Training Step: 357...  Training loss: 2.2363...  1.0572 sec/batch
# Epoch: 2/20...  Training Step: 358...  Training loss: 2.2821...  1.0602 sec/batch
# Epoch: 2/20...  Training Step: 359...  Training loss: 2.2716...  1.0512 sec/batch
# Epoch: 2/20...  Training Step: 360...  Training loss: 2.2385...  1.0811 sec/batch
# Epoch: 2/20...  Training Step: 361...  Training loss: 2.2599...  1.0535 sec/batch
# Epoch: 2/20...  Training Step: 362...  Training loss: 2.2516...  1.0983 sec/batch
# Epoch: 2/20...  Training Step: 363...  Training loss: 2.2594...  1.0963 sec/batch
# Epoch: 2/20...  Training Step: 364...  Training loss: 2.2602...  1.1238 sec/batch
# Epoch: 2/20...  Training Step: 365...  Training loss: 2.2633...  1.0918 sec/batch
# Epoch: 2/20...  Training Step: 366...  Training loss: 2.2679...  1.1396 sec/batch
# Epoch: 2/20...  Training Step: 367...  Training loss: 2.2538...  1.1203 sec/batch
# Epoch: 2/20...  Training Step: 368...  Training loss: 2.2396...  1.0847 sec/batch
# Epoch: 2/20...  Training Step: 369...  Training loss: 2.2354...  1.0878 sec/batch
# Epoch: 2/20...  Training Step: 370...  Training loss: 2.2461...  1.0784 sec/batch
# Epoch: 2/20...  Training Step: 371...  Training loss: 2.2690...  1.0810 sec/batch
# Epoch: 2/20...  Training Step: 372...  Training loss: 2.2576...  1.1078 sec/batch
# Epoch: 2/20...  Training Step: 373...  Training loss: 2.2490...  1.0999 sec/batch
# Epoch: 2/20...  Training Step: 374...  Training loss: 2.2452...  1.0933 sec/batch
# Epoch: 2/20...  Training Step: 375...  Training loss: 2.2275...  1.1298 sec/batch
# Epoch: 2/20...  Training Step: 376...  Training loss: 2.2305...  1.0515 sec/batch
# Epoch: 2/20...  Training Step: 377...  Training loss: 2.2147...  1.0457 sec/batch
# Epoch: 2/20...  Training Step: 378...  Training loss: 2.2098...  1.1452 sec/batch
# Epoch: 2/20...  Training Step: 379...  Training loss: 2.2183...  1.2811 sec/batch
# Epoch: 2/20...  Training Step: 380...  Training loss: 2.2309...  1.1361 sec/batch
# Epoch: 2/20...  Training Step: 381...  Training loss: 2.2318...  1.1050 sec/batch
# Epoch: 2/20...  Training Step: 382...  Training loss: 2.2478...  1.1841 sec/batch
# Epoch: 2/20...  Training Step: 383...  Training loss: 2.2459...  1.1392 sec/batch
# Epoch: 2/20...  Training Step: 384...  Training loss: 2.2205...  1.3336 sec/batch
# Epoch: 2/20...  Training Step: 385...  Training loss: 2.2154...  1.1867 sec/batch
# Epoch: 2/20...  Training Step: 386...  Training loss: 2.2025...  1.2639 sec/batch
# Epoch: 2/20...  Training Step: 387...  Training loss: 2.2025...  1.2112 sec/batch
# Epoch: 2/20...  Training Step: 388...  Training loss: 2.2158...  1.0909 sec/batch
# Epoch: 2/20...  Training Step: 389...  Training loss: 2.2240...  1.0960 sec/batch
# Epoch: 2/20...  Training Step: 390...  Training loss: 2.1862...  1.0712 sec/batch
# Epoch: 2/20...  Training Step: 391...  Training loss: 2.2138...  1.0814 sec/batch
# Epoch: 2/20...  Training Step: 392...  Training loss: 2.2093...  1.0916 sec/batch
# Epoch: 2/20...  Training Step: 393...  Training loss: 2.1951...  1.0787 sec/batch
# Epoch: 2/20...  Training Step: 394...  Training loss: 2.2028...  1.0993 sec/batch
# Epoch: 2/20...  Training Step: 395...  Training loss: 2.2142...  1.0933 sec/batch
# Epoch: 2/20...  Training Step: 396...  Training loss: 2.1974...  1.1117 sec/batch
# Epoch: 3/20...  Training Step: 397...  Training loss: 2.3037...  1.0896 sec/batch
# Epoch: 3/20...  Training Step: 398...  Training loss: 2.1795...  1.0840 sec/batch
# Epoch: 3/20...  Training Step: 399...  Training loss: 2.1905...  1.0936 sec/batch
# Epoch: 3/20...  Training Step: 400...  Training loss: 2.1900...  1.1005 sec/batch
# Epoch: 3/20...  Training Step: 401...  Training loss: 2.1995...  1.0646 sec/batch
# Epoch: 3/20...  Training Step: 402...  Training loss: 2.1812...  1.0656 sec/batch
# Epoch: 3/20...  Training Step: 403...  Training loss: 2.2030...  1.0929 sec/batch
# Epoch: 3/20...  Training Step: 404...  Training loss: 2.2083...  1.0716 sec/batch
# Epoch: 3/20...  Training Step: 405...  Training loss: 2.2327...  1.0958 sec/batch
# Epoch: 3/20...  Training Step: 406...  Training loss: 2.1915...  1.1136 sec/batch
# Epoch: 3/20...  Training Step: 407...  Training loss: 2.1771...  1.0791 sec/batch
# Epoch: 3/20...  Training Step: 408...  Training loss: 2.1792...  1.0974 sec/batch
# Epoch: 3/20...  Training Step: 409...  Training loss: 2.1966...  1.0813 sec/batch
# Epoch: 3/20...  Training Step: 410...  Training loss: 2.2216...  1.1127 sec/batch
# Epoch: 3/20...  Training Step: 411...  Training loss: 2.1942...  1.0777 sec/batch
# Epoch: 3/20...  Training Step: 412...  Training loss: 2.1842...  1.1988 sec/batch
# Epoch: 3/20...  Training Step: 413...  Training loss: 2.1833...  1.2837 sec/batch
# Epoch: 3/20...  Training Step: 414...  Training loss: 2.2213...  1.1100 sec/batch
# Epoch: 3/20...  Training Step: 415...  Training loss: 2.1990...  1.0382 sec/batch
# Epoch: 3/20...  Training Step: 416...  Training loss: 2.1726...  1.0336 sec/batch
# Epoch: 3/20...  Training Step: 417...  Training loss: 2.1902...  0.9971 sec/batch
# Epoch: 3/20...  Training Step: 418...  Training loss: 2.2219...  0.9721 sec/batch
# Epoch: 3/20...  Training Step: 419...  Training loss: 2.1923...  1.0107 sec/batch
# Epoch: 3/20...  Training Step: 420...  Training loss: 2.1810...  0.9771 sec/batch
# Epoch: 3/20...  Training Step: 421...  Training loss: 2.1737...  0.9868 sec/batch
# Epoch: 3/20...  Training Step: 422...  Training loss: 2.1645...  0.9990 sec/batch
# Epoch: 3/20...  Training Step: 423...  Training loss: 2.1666...  1.0120 sec/batch
# Epoch: 3/20...  Training Step: 424...  Training loss: 2.1857...  1.0142 sec/batch
# Epoch: 3/20...  Training Step: 425...  Training loss: 2.2134...  1.0000 sec/batch
# Epoch: 3/20...  Training Step: 426...  Training loss: 2.1844...  1.0133 sec/batch
# Epoch: 3/20...  Training Step: 427...  Training loss: 2.1916...  0.9870 sec/batch
# Epoch: 3/20...  Training Step: 428...  Training loss: 2.1593...  0.9961 sec/batch
# Epoch: 3/20...  Training Step: 429...  Training loss: 2.1705...  1.0063 sec/batch
# Epoch: 3/20...  Training Step: 430...  Training loss: 2.2056...  1.0305 sec/batch
# Epoch: 3/20...  Training Step: 431...  Training loss: 2.1527...  1.0111 sec/batch
# Epoch: 3/20...  Training Step: 432...  Training loss: 2.1785...  0.9951 sec/batch
# Epoch: 3/20...  Training Step: 433...  Training loss: 2.1634...  0.9923 sec/batch
# Epoch: 3/20...  Training Step: 434...  Training loss: 2.1360...  1.0181 sec/batch
# Epoch: 3/20...  Training Step: 435...  Training loss: 2.1463...  0.9882 sec/batch
# Epoch: 3/20...  Training Step: 436...  Training loss: 2.1358...  1.0030 sec/batch
# Epoch: 3/20...  Training Step: 437...  Training loss: 2.1540...  0.9760 sec/batch
# Epoch: 3/20...  Training Step: 438...  Training loss: 2.1637...  1.0153 sec/batch
# Epoch: 3/20...  Training Step: 439...  Training loss: 2.1422...  0.9994 sec/batch
# Epoch: 3/20...  Training Step: 440...  Training loss: 2.1354...  1.0163 sec/batch
# Epoch: 3/20...  Training Step: 441...  Training loss: 2.1645...  0.9908 sec/batch
# Epoch: 3/20...  Training Step: 442...  Training loss: 2.1110...  1.0065 sec/batch
# Epoch: 3/20...  Training Step: 443...  Training loss: 2.1732...  1.0360 sec/batch
# Epoch: 3/20...  Training Step: 444...  Training loss: 2.1400...  1.0030 sec/batch
# Epoch: 3/20...  Training Step: 445...  Training loss: 2.1416...  0.9966 sec/batch
# Epoch: 3/20...  Training Step: 446...  Training loss: 2.1886...  0.9890 sec/batch
# Epoch: 3/20...  Training Step: 447...  Training loss: 2.1252...  0.9874 sec/batch
# Epoch: 3/20...  Training Step: 448...  Training loss: 2.1895...  1.0144 sec/batch
# Epoch: 3/20...  Training Step: 449...  Training loss: 2.1464...  1.0257 sec/batch
# Epoch: 3/20...  Training Step: 450...  Training loss: 2.1326...  0.9761 sec/batch
# Epoch: 3/20...  Training Step: 451...  Training loss: 2.1341...  0.9981 sec/batch
# Epoch: 3/20...  Training Step: 452...  Training loss: 2.1546...  0.9942 sec/batch
# Epoch: 3/20...  Training Step: 453...  Training loss: 2.1531...  0.9974 sec/batch
# Epoch: 3/20...  Training Step: 454...  Training loss: 2.1431...  1.0038 sec/batch
# Epoch: 3/20...  Training Step: 455...  Training loss: 2.1248...  1.0185 sec/batch
# Epoch: 3/20...  Training Step: 456...  Training loss: 2.1634...  0.9972 sec/batch
# Epoch: 3/20...  Training Step: 457...  Training loss: 2.1270...  0.9895 sec/batch
# Epoch: 3/20...  Training Step: 458...  Training loss: 2.1701...  0.9575 sec/batch
# Epoch: 3/20...  Training Step: 459...  Training loss: 2.1730...  1.0228 sec/batch
# Epoch: 3/20...  Training Step: 460...  Training loss: 2.1458...  0.9999 sec/batch
# Epoch: 3/20...  Training Step: 461...  Training loss: 2.1320...  0.9845 sec/batch
# Epoch: 3/20...  Training Step: 462...  Training loss: 2.1619...  0.9780 sec/batch
# Epoch: 3/20...  Training Step: 463...  Training loss: 2.1513...  0.9951 sec/batch
# Epoch: 3/20...  Training Step: 464...  Training loss: 2.1066...  0.9907 sec/batch
# Epoch: 3/20...  Training Step: 465...  Training loss: 2.1187...  1.0024 sec/batch
# Epoch: 3/20...  Training Step: 466...  Training loss: 2.1361...  0.9860 sec/batch
# Epoch: 3/20...  Training Step: 467...  Training loss: 2.1657...  1.0116 sec/batch
# Epoch: 3/20...  Training Step: 468...  Training loss: 2.1402...  0.9969 sec/batch
# Epoch: 3/20...  Training Step: 469...  Training loss: 2.1515...  0.9871 sec/batch
# Epoch: 3/20...  Training Step: 470...  Training loss: 2.1143...  0.9893 sec/batch
# Epoch: 3/20...  Training Step: 471...  Training loss: 2.1231...  0.9969 sec/batch
# Epoch: 3/20...  Training Step: 472...  Training loss: 2.1684...  1.0076 sec/batch
# Epoch: 3/20...  Training Step: 473...  Training loss: 2.1351...  1.0029 sec/batch
# Epoch: 3/20...  Training Step: 474...  Training loss: 2.1400...  0.9783 sec/batch
# Epoch: 3/20...  Training Step: 475...  Training loss: 2.1081...  0.9965 sec/batch
# Epoch: 3/20...  Training Step: 476...  Training loss: 2.1155...  1.0079 sec/batch
# Epoch: 3/20...  Training Step: 477...  Training loss: 2.0906...  1.0085 sec/batch
# Epoch: 3/20...  Training Step: 478...  Training loss: 2.1362...  0.9887 sec/batch
# Epoch: 3/20...  Training Step: 479...  Training loss: 2.0996...  0.9933 sec/batch
# Epoch: 3/20...  Training Step: 480...  Training loss: 2.1140...  0.9912 sec/batch
# Epoch: 3/20...  Training Step: 481...  Training loss: 2.0884...  0.9868 sec/batch
# Epoch: 3/20...  Training Step: 482...  Training loss: 2.1063...  0.9733 sec/batch
# Epoch: 3/20...  Training Step: 483...  Training loss: 2.1239...  0.9984 sec/batch
# Epoch: 3/20...  Training Step: 484...  Training loss: 2.1079...  1.0005 sec/batch
# Epoch: 3/20...  Training Step: 485...  Training loss: 2.0835...  0.9985 sec/batch
# Epoch: 3/20...  Training Step: 486...  Training loss: 2.1293...  0.9916 sec/batch
# Epoch: 3/20...  Training Step: 487...  Training loss: 2.0986...  0.9933 sec/batch
# Epoch: 3/20...  Training Step: 488...  Training loss: 2.1212...  1.0137 sec/batch
# Epoch: 3/20...  Training Step: 489...  Training loss: 2.0830...  0.9947 sec/batch
# Epoch: 3/20...  Training Step: 490...  Training loss: 2.0857...  1.0249 sec/batch
# Epoch: 3/20...  Training Step: 491...  Training loss: 2.0827...  0.9906 sec/batch
# Epoch: 3/20...  Training Step: 492...  Training loss: 2.1023...  0.9885 sec/batch
# Epoch: 3/20...  Training Step: 493...  Training loss: 2.0979...  0.9830 sec/batch
# Epoch: 3/20...  Training Step: 494...  Training loss: 2.0798...  0.9919 sec/batch
# Epoch: 3/20...  Training Step: 495...  Training loss: 2.0916...  0.9963 sec/batch
# Epoch: 3/20...  Training Step: 496...  Training loss: 2.0785...  0.9777 sec/batch
# Epoch: 3/20...  Training Step: 497...  Training loss: 2.1141...  0.9928 sec/batch
# Epoch: 3/20...  Training Step: 498...  Training loss: 2.1099...  0.9983 sec/batch
# Epoch: 3/20...  Training Step: 499...  Training loss: 2.0814...  0.9571 sec/batch
# Epoch: 3/20...  Training Step: 500...  Training loss: 2.0847...  0.9868 sec/batch
# Epoch: 3/20...  Training Step: 501...  Training loss: 2.0819...  0.9971 sec/batch
# Epoch: 3/20...  Training Step: 502...  Training loss: 2.0930...  1.0046 sec/batch
# Epoch: 3/20...  Training Step: 503...  Training loss: 2.0907...  0.9956 sec/batch
# Epoch: 3/20...  Training Step: 504...  Training loss: 2.1006...  0.9920 sec/batch
# Epoch: 3/20...  Training Step: 505...  Training loss: 2.1112...  0.9853 sec/batch
# Epoch: 3/20...  Training Step: 506...  Training loss: 2.0928...  0.9863 sec/batch
# Epoch: 3/20...  Training Step: 507...  Training loss: 2.1005...  1.0044 sec/batch
# Epoch: 3/20...  Training Step: 508...  Training loss: 2.0899...  1.0031 sec/batch
# Epoch: 3/20...  Training Step: 509...  Training loss: 2.0967...  0.9832 sec/batch
# Epoch: 3/20...  Training Step: 510...  Training loss: 2.0745...  1.0161 sec/batch
# Epoch: 3/20...  Training Step: 511...  Training loss: 2.0809...  0.9856 sec/batch
# Epoch: 3/20...  Training Step: 512...  Training loss: 2.0389...  0.9973 sec/batch
# Epoch: 3/20...  Training Step: 513...  Training loss: 2.0884...  1.0157 sec/batch
# Epoch: 3/20...  Training Step: 514...  Training loss: 2.0791...  1.0331 sec/batch
# Epoch: 3/20...  Training Step: 515...  Training loss: 2.1022...  1.0125 sec/batch
# Epoch: 3/20...  Training Step: 516...  Training loss: 2.0890...  0.9959 sec/batch
# Epoch: 3/20...  Training Step: 517...  Training loss: 2.1050...  0.9943 sec/batch
# Epoch: 3/20...  Training Step: 518...  Training loss: 2.0604...  0.9819 sec/batch
# Epoch: 3/20...  Training Step: 519...  Training loss: 2.0768...  1.0154 sec/batch
# Epoch: 3/20...  Training Step: 520...  Training loss: 2.1147...  0.9963 sec/batch
# Epoch: 3/20...  Training Step: 521...  Training loss: 2.0803...  0.9897 sec/batch
# Epoch: 3/20...  Training Step: 522...  Training loss: 2.0393...  0.9697 sec/batch
# Epoch: 3/20...  Training Step: 523...  Training loss: 2.0997...  0.9981 sec/batch
# Epoch: 3/20...  Training Step: 524...  Training loss: 2.0965...  0.9915 sec/batch
# Epoch: 3/20...  Training Step: 525...  Training loss: 2.0791...  0.9754 sec/batch
# Epoch: 3/20...  Training Step: 526...  Training loss: 2.0799...  1.0196 sec/batch
# Epoch: 3/20...  Training Step: 527...  Training loss: 2.0607...  1.0068 sec/batch
# Epoch: 3/20...  Training Step: 528...  Training loss: 2.0551...  0.9765 sec/batch
# Epoch: 3/20...  Training Step: 529...  Training loss: 2.1011...  0.9948 sec/batch
# Epoch: 3/20...  Training Step: 530...  Training loss: 2.0882...  0.9903 sec/batch
# Epoch: 3/20...  Training Step: 531...  Training loss: 2.0665...  1.0020 sec/batch
# Epoch: 3/20...  Training Step: 532...  Training loss: 2.0885...  0.9815 sec/batch
# Epoch: 3/20...  Training Step: 533...  Training loss: 2.0852...  0.9717 sec/batch
# Epoch: 3/20...  Training Step: 534...  Training loss: 2.0783...  0.9716 sec/batch
# Epoch: 3/20...  Training Step: 535...  Training loss: 2.1137...  0.9801 sec/batch
# Epoch: 3/20...  Training Step: 536...  Training loss: 2.0679...  1.0165 sec/batch
# Epoch: 3/20...  Training Step: 537...  Training loss: 2.1055...  1.0158 sec/batch
# Epoch: 3/20...  Training Step: 538...  Training loss: 2.0592...  1.0001 sec/batch
# Epoch: 3/20...  Training Step: 539...  Training loss: 2.0716...  0.9799 sec/batch
# Epoch: 3/20...  Training Step: 540...  Training loss: 2.0742...  0.9855 sec/batch
# Epoch: 3/20...  Training Step: 541...  Training loss: 2.0572...  0.9839 sec/batch
# Epoch: 3/20...  Training Step: 542...  Training loss: 2.0826...  1.0255 sec/batch
# Epoch: 3/20...  Training Step: 543...  Training loss: 2.0855...  1.0147 sec/batch
# Epoch: 3/20...  Training Step: 544...  Training loss: 2.0881...  0.9988 sec/batch
# Epoch: 3/20...  Training Step: 545...  Training loss: 2.0555...  0.9902 sec/batch
# Epoch: 3/20...  Training Step: 546...  Training loss: 2.0556...  0.9912 sec/batch
# Epoch: 3/20...  Training Step: 547...  Training loss: 2.0541...  0.9896 sec/batch
# Epoch: 3/20...  Training Step: 548...  Training loss: 2.0924...  1.0018 sec/batch
# Epoch: 3/20...  Training Step: 549...  Training loss: 2.0808...  0.9931 sec/batch
# Epoch: 3/20...  Training Step: 550...  Training loss: 2.0700...  1.0395 sec/batch
# Epoch: 3/20...  Training Step: 551...  Training loss: 2.0544...  1.0002 sec/batch
# Epoch: 3/20...  Training Step: 552...  Training loss: 2.0511...  0.9761 sec/batch
# Epoch: 3/20...  Training Step: 553...  Training loss: 2.0646...  0.9707 sec/batch
# Epoch: 3/20...  Training Step: 554...  Training loss: 2.0553...  0.9818 sec/batch
# Epoch: 3/20...  Training Step: 555...  Training loss: 2.0337...  0.9781 sec/batch
# Epoch: 3/20...  Training Step: 556...  Training loss: 2.0899...  0.9996 sec/batch
# Epoch: 3/20...  Training Step: 557...  Training loss: 2.0771...  1.0073 sec/batch
# Epoch: 3/20...  Training Step: 558...  Training loss: 2.0578...  1.0099 sec/batch
# Epoch: 3/20...  Training Step: 559...  Training loss: 2.0670...  0.9779 sec/batch
# Epoch: 3/20...  Training Step: 560...  Training loss: 2.0588...  0.9881 sec/batch
# Epoch: 3/20...  Training Step: 561...  Training loss: 2.0574...  0.9936 sec/batch
# Epoch: 3/20...  Training Step: 562...  Training loss: 2.0540...  1.0108 sec/batch
# Epoch: 3/20...  Training Step: 563...  Training loss: 2.0588...  1.0024 sec/batch
# Epoch: 3/20...  Training Step: 564...  Training loss: 2.0959...  0.9926 sec/batch
# Epoch: 3/20...  Training Step: 565...  Training loss: 2.0457...  1.0266 sec/batch
# Epoch: 3/20...  Training Step: 566...  Training loss: 2.0505...  0.9959 sec/batch
# Epoch: 3/20...  Training Step: 567...  Training loss: 2.0328...  0.9784 sec/batch
# Epoch: 3/20...  Training Step: 568...  Training loss: 2.0444...  1.0127 sec/batch
# Epoch: 3/20...  Training Step: 569...  Training loss: 2.0682...  1.0007 sec/batch
# Epoch: 3/20...  Training Step: 570...  Training loss: 2.0611...  0.9989 sec/batch
# Epoch: 3/20...  Training Step: 571...  Training loss: 2.0617...  1.0141 sec/batch
# Epoch: 3/20...  Training Step: 572...  Training loss: 2.0454...  0.9913 sec/batch
# Epoch: 3/20...  Training Step: 573...  Training loss: 2.0376...  0.9920 sec/batch
# Epoch: 3/20...  Training Step: 574...  Training loss: 2.0530...  0.9989 sec/batch
# Epoch: 3/20...  Training Step: 575...  Training loss: 2.0280...  1.0001 sec/batch
# Epoch: 3/20...  Training Step: 576...  Training loss: 2.0122...  0.9840 sec/batch
# Epoch: 3/20...  Training Step: 577...  Training loss: 2.0294...  0.9789 sec/batch
# Epoch: 3/20...  Training Step: 578...  Training loss: 2.0471...  0.9932 sec/batch
# Epoch: 3/20...  Training Step: 579...  Training loss: 2.0507...  0.9741 sec/batch
# Epoch: 3/20...  Training Step: 580...  Training loss: 2.0676...  0.9766 sec/batch
# Epoch: 3/20...  Training Step: 581...  Training loss: 2.0547...  1.0090 sec/batch
# Epoch: 3/20...  Training Step: 582...  Training loss: 2.0337...  0.9884 sec/batch
# Epoch: 3/20...  Training Step: 583...  Training loss: 2.0455...  0.9912 sec/batch
# Epoch: 3/20...  Training Step: 584...  Training loss: 2.0291...  1.0115 sec/batch
# Epoch: 3/20...  Training Step: 585...  Training loss: 2.0305...  1.0227 sec/batch
# Epoch: 3/20...  Training Step: 586...  Training loss: 2.0451...  1.0008 sec/batch
# ...
# Epoch: 20/20...  Training Step: 3771...  Training loss: 1.4849...  0.9901 sec/batch
# Epoch: 20/20...  Training Step: 3772...  Training loss: 1.4595...  1.0067 sec/batch
# Epoch: 20/20...  Training Step: 3773...  Training loss: 1.4462...  0.9944 sec/batch
# Epoch: 20/20...  Training Step: 3774...  Training loss: 1.4607...  0.9932 sec/batch
# Epoch: 20/20...  Training Step: 3775...  Training loss: 1.4498...  0.9921 sec/batch
# Epoch: 20/20...  Training Step: 3776...  Training loss: 1.4953...  1.0047 sec/batch
# Epoch: 20/20...  Training Step: 3777...  Training loss: 1.4542...  1.0085 sec/batch
# Epoch: 20/20...  Training Step: 3778...  Training loss: 1.4563...  1.0028 sec/batch
# Epoch: 20/20...  Training Step: 3779...  Training loss: 1.4852...  0.9921 sec/batch
# Epoch: 20/20...  Training Step: 3780...  Training loss: 1.4828...  1.0411 sec/batch
# Epoch: 20/20...  Training Step: 3781...  Training loss: 1.4638...  1.0133 sec/batch
# Epoch: 20/20...  Training Step: 3782...  Training loss: 1.4929...  1.0109 sec/batch
# Epoch: 20/20...  Training Step: 3783...  Training loss: 1.4577...  1.0081 sec/batch
# Epoch: 20/20...  Training Step: 3784...  Training loss: 1.4830...  1.0119 sec/batch
# Epoch: 20/20...  Training Step: 3785...  Training loss: 1.4549...  0.9994 sec/batch
# Epoch: 20/20...  Training Step: 3786...  Training loss: 1.4842...  1.0061 sec/batch
# Epoch: 20/20...  Training Step: 3787...  Training loss: 1.4672...  1.0010 sec/batch
# Epoch: 20/20...  Training Step: 3788...  Training loss: 1.4320...  1.0150 sec/batch
# Epoch: 20/20...  Training Step: 3789...  Training loss: 1.4367...  1.0162 sec/batch
# Epoch: 20/20...  Training Step: 3790...  Training loss: 1.4820...  1.0314 sec/batch
# Epoch: 20/20...  Training Step: 3791...  Training loss: 1.4860...  1.0026 sec/batch
# Epoch: 20/20...  Training Step: 3792...  Training loss: 1.4848...  0.9939 sec/batch
# Epoch: 20/20...  Training Step: 3793...  Training loss: 1.4559...  1.0279 sec/batch
# Epoch: 20/20...  Training Step: 3794...  Training loss: 1.4427...  1.0082 sec/batch
# Epoch: 20/20...  Training Step: 3795...  Training loss: 1.4908...  1.0071 sec/batch
# Epoch: 20/20...  Training Step: 3796...  Training loss: 1.4774...  1.0015 sec/batch
# Epoch: 20/20...  Training Step: 3797...  Training loss: 1.4579...  1.0160 sec/batch
# Epoch: 20/20...  Training Step: 3798...  Training loss: 1.4685...  1.0229 sec/batch
# Epoch: 20/20...  Training Step: 3799...  Training loss: 1.4409...  1.0160 sec/batch
# Epoch: 20/20...  Training Step: 3800...  Training loss: 1.4324...  1.0333 sec/batch
# Epoch: 20/20...  Training Step: 3801...  Training loss: 1.4171...  0.9915 sec/batch
# Epoch: 20/20...  Training Step: 3802...  Training loss: 1.4502...  0.9846 sec/batch
# Epoch: 20/20...  Training Step: 3803...  Training loss: 1.4400...  1.0348 sec/batch
# Epoch: 20/20...  Training Step: 3804...  Training loss: 1.4916...  0.9916 sec/batch
# Epoch: 20/20...  Training Step: 3805...  Training loss: 1.4410...  0.9967 sec/batch
# Epoch: 20/20...  Training Step: 3806...  Training loss: 1.4402...  1.0037 sec/batch
# Epoch: 20/20...  Training Step: 3807...  Training loss: 1.4785...  1.0155 sec/batch
# Epoch: 20/20...  Training Step: 3808...  Training loss: 1.4377...  1.0027 sec/batch
# Epoch: 20/20...  Training Step: 3809...  Training loss: 1.4634...  1.0123 sec/batch
# Epoch: 20/20...  Training Step: 3810...  Training loss: 1.4577...  1.0339 sec/batch
# Epoch: 20/20...  Training Step: 3811...  Training loss: 1.4608...  1.0055 sec/batch
# Epoch: 20/20...  Training Step: 3812...  Training loss: 1.4876...  1.0166 sec/batch
# Epoch: 20/20...  Training Step: 3813...  Training loss: 1.4422...  0.9994 sec/batch
# Epoch: 20/20...  Training Step: 3814...  Training loss: 1.5069...  0.9962 sec/batch
# Epoch: 20/20...  Training Step: 3815...  Training loss: 1.4779...  0.9939 sec/batch
# Epoch: 20/20...  Training Step: 3816...  Training loss: 1.4812...  1.0068 sec/batch
# Epoch: 20/20...  Training Step: 3817...  Training loss: 1.4592...  0.9971 sec/batch
# Epoch: 20/20...  Training Step: 3818...  Training loss: 1.4676...  0.9923 sec/batch
# Epoch: 20/20...  Training Step: 3819...  Training loss: 1.4858...  1.0179 sec/batch
# Epoch: 20/20...  Training Step: 3820...  Training loss: 1.4494...  0.9975 sec/batch
# Epoch: 20/20...  Training Step: 3821...  Training loss: 1.4395...  0.9848 sec/batch
# Epoch: 20/20...  Training Step: 3822...  Training loss: 1.5061...  1.0023 sec/batch
# Epoch: 20/20...  Training Step: 3823...  Training loss: 1.4687...  1.0094 sec/batch
# Epoch: 20/20...  Training Step: 3824...  Training loss: 1.5159...  0.9934 sec/batch
# Epoch: 20/20...  Training Step: 3825...  Training loss: 1.4874...  0.9868 sec/batch
# Epoch: 20/20...  Training Step: 3826...  Training loss: 1.4683...  1.0099 sec/batch
# Epoch: 20/20...  Training Step: 3827...  Training loss: 1.4539...  1.0413 sec/batch
# Epoch: 20/20...  Training Step: 3828...  Training loss: 1.4769...  1.0168 sec/batch
# Epoch: 20/20...  Training Step: 3829...  Training loss: 1.4886...  1.0268 sec/batch
# Epoch: 20/20...  Training Step: 3830...  Training loss: 1.4497...  0.9960 sec/batch
# Epoch: 20/20...  Training Step: 3831...  Training loss: 1.4632...  0.9864 sec/batch
# Epoch: 20/20...  Training Step: 3832...  Training loss: 1.4528...  1.0154 sec/batch
# Epoch: 20/20...  Training Step: 3833...  Training loss: 1.5011...  0.9899 sec/batch
# Epoch: 20/20...  Training Step: 3834...  Training loss: 1.4915...  1.0097 sec/batch
# Epoch: 20/20...  Training Step: 3835...  Training loss: 1.4918...  0.9903 sec/batch
# Epoch: 20/20...  Training Step: 3836...  Training loss: 1.4480...  0.9869 sec/batch
# Epoch: 20/20...  Training Step: 3837...  Training loss: 1.4638...  0.9938 sec/batch
# Epoch: 20/20...  Training Step: 3838...  Training loss: 1.4768...  1.0207 sec/batch
# Epoch: 20/20...  Training Step: 3839...  Training loss: 1.4657...  1.0066 sec/batch
# Epoch: 20/20...  Training Step: 3840...  Training loss: 1.4539...  1.0309 sec/batch
# Epoch: 20/20...  Training Step: 3841...  Training loss: 1.4269...  1.0049 sec/batch
# Epoch: 20/20...  Training Step: 3842...  Training loss: 1.4625...  1.0088 sec/batch
# Epoch: 20/20...  Training Step: 3843...  Training loss: 1.4261...  0.9665 sec/batch
# Epoch: 20/20...  Training Step: 3844...  Training loss: 1.4642...  1.0300 sec/batch
# Epoch: 20/20...  Training Step: 3845...  Training loss: 1.4323...  0.9987 sec/batch
# Epoch: 20/20...  Training Step: 3846...  Training loss: 1.4620...  1.0009 sec/batch
# Epoch: 20/20...  Training Step: 3847...  Training loss: 1.4395...  1.0043 sec/batch
# Epoch: 20/20...  Training Step: 3848...  Training loss: 1.4602...  0.9968 sec/batch
# Epoch: 20/20...  Training Step: 3849...  Training loss: 1.4350...  0.9979 sec/batch
# Epoch: 20/20...  Training Step: 3850...  Training loss: 1.4349...  1.0083 sec/batch
# Epoch: 20/20...  Training Step: 3851...  Training loss: 1.4201...  0.9761 sec/batch
# Epoch: 20/20...  Training Step: 3852...  Training loss: 1.4749...  1.0169 sec/batch
# Epoch: 20/20...  Training Step: 3853...  Training loss: 1.4341...  1.0124 sec/batch
# Epoch: 20/20...  Training Step: 3854...  Training loss: 1.4504...  1.0032 sec/batch
# Epoch: 20/20...  Training Step: 3855...  Training loss: 1.4351...  1.0026 sec/batch
# Epoch: 20/20...  Training Step: 3856...  Training loss: 1.4417...  1.0045 sec/batch
# Epoch: 20/20...  Training Step: 3857...  Training loss: 1.4389...  1.0009 sec/batch
# Epoch: 20/20...  Training Step: 3858...  Training loss: 1.4745...  1.0455 sec/batch
# Epoch: 20/20...  Training Step: 3859...  Training loss: 1.4693...  1.0217 sec/batch
# Epoch: 20/20...  Training Step: 3860...  Training loss: 1.4251...  1.0075 sec/batch
# Epoch: 20/20...  Training Step: 3861...  Training loss: 1.4371...  1.0071 sec/batch
# Epoch: 20/20...  Training Step: 3862...  Training loss: 1.4223...  1.0264 sec/batch
# Epoch: 20/20...  Training Step: 3863...  Training loss: 1.4597...  1.0131 sec/batch
# Epoch: 20/20...  Training Step: 3864...  Training loss: 1.4583...  1.0055 sec/batch
# Epoch: 20/20...  Training Step: 3865...  Training loss: 1.4586...  1.0165 sec/batch
# Epoch: 20/20...  Training Step: 3866...  Training loss: 1.4508...  0.9964 sec/batch
# Epoch: 20/20...  Training Step: 3867...  Training loss: 1.4510...  0.9969 sec/batch
# Epoch: 20/20...  Training Step: 3868...  Training loss: 1.4544...  1.0075 sec/batch
# Epoch: 20/20...  Training Step: 3869...  Training loss: 1.4623...  0.9954 sec/batch
# Epoch: 20/20...  Training Step: 3870...  Training loss: 1.4588...  1.0011 sec/batch
# Epoch: 20/20...  Training Step: 3871...  Training loss: 1.4605...  0.9957 sec/batch
# Epoch: 20/20...  Training Step: 3872...  Training loss: 1.4740...  0.9948 sec/batch
# Epoch: 20/20...  Training Step: 3873...  Training loss: 1.4437...  1.0055 sec/batch
# Epoch: 20/20...  Training Step: 3874...  Training loss: 1.4625...  1.0155 sec/batch
# Epoch: 20/20...  Training Step: 3875...  Training loss: 1.4590...  0.9911 sec/batch
# Epoch: 20/20...  Training Step: 3876...  Training loss: 1.4577...  0.9946 sec/batch
# Epoch: 20/20...  Training Step: 3877...  Training loss: 1.4317...  0.9977 sec/batch
# Epoch: 20/20...  Training Step: 3878...  Training loss: 1.4197...  0.9837 sec/batch
# Epoch: 20/20...  Training Step: 3879...  Training loss: 1.4659...  0.9950 sec/batch
# Epoch: 20/20...  Training Step: 3880...  Training loss: 1.4570...  1.0167 sec/batch
# Epoch: 20/20...  Training Step: 3881...  Training loss: 1.4491...  0.9889 sec/batch
# Epoch: 20/20...  Training Step: 3882...  Training loss: 1.4525...  1.0103 sec/batch
# Epoch: 20/20...  Training Step: 3883...  Training loss: 1.4650...  0.9790 sec/batch
# Epoch: 20/20...  Training Step: 3884...  Training loss: 1.4148...  1.0343 sec/batch
# Epoch: 20/20...  Training Step: 3885...  Training loss: 1.4229...  0.9898 sec/batch
# Epoch: 20/20...  Training Step: 3886...  Training loss: 1.4676...  0.9913 sec/batch
# Epoch: 20/20...  Training Step: 3887...  Training loss: 1.4536...  1.0020 sec/batch
# Epoch: 20/20...  Training Step: 3888...  Training loss: 1.4187...  0.9880 sec/batch
# Epoch: 20/20...  Training Step: 3889...  Training loss: 1.4688...  0.9976 sec/batch
# Epoch: 20/20...  Training Step: 3890...  Training loss: 1.4758...  0.9909 sec/batch
# Epoch: 20/20...  Training Step: 3891...  Training loss: 1.4514...  1.0020 sec/batch
# Epoch: 20/20...  Training Step: 3892...  Training loss: 1.4221...  1.0082 sec/batch
# Epoch: 20/20...  Training Step: 3893...  Training loss: 1.4145...  0.9854 sec/batch
# Epoch: 20/20...  Training Step: 3894...  Training loss: 1.4269...  1.0273 sec/batch
# Epoch: 20/20...  Training Step: 3895...  Training loss: 1.4758...  1.0049 sec/batch
# Epoch: 20/20...  Training Step: 3896...  Training loss: 1.4745...  0.9996 sec/batch
# Epoch: 20/20...  Training Step: 3897...  Training loss: 1.4592...  1.0117 sec/batch
# Epoch: 20/20...  Training Step: 3898...  Training loss: 1.4707...  1.0286 sec/batch
# Epoch: 20/20...  Training Step: 3899...  Training loss: 1.4855...  1.0246 sec/batch
# Epoch: 20/20...  Training Step: 3900...  Training loss: 1.4736...  1.0053 sec/batch
# Epoch: 20/20...  Training Step: 3901...  Training loss: 1.4667...  0.9972 sec/batch
# Epoch: 20/20...  Training Step: 3902...  Training loss: 1.4593...  0.9927 sec/batch
# Epoch: 20/20...  Training Step: 3903...  Training loss: 1.5210...  1.0058 sec/batch
# Epoch: 20/20...  Training Step: 3904...  Training loss: 1.4655...  1.0098 sec/batch
# Epoch: 20/20...  Training Step: 3905...  Training loss: 1.4572...  1.0055 sec/batch
# Epoch: 20/20...  Training Step: 3906...  Training loss: 1.4899...  0.9864 sec/batch
# Epoch: 20/20...  Training Step: 3907...  Training loss: 1.4435...  0.9902 sec/batch
# Epoch: 20/20...  Training Step: 3908...  Training loss: 1.4645...  0.9976 sec/batch
# Epoch: 20/20...  Training Step: 3909...  Training loss: 1.4673...  1.0255 sec/batch
# Epoch: 20/20...  Training Step: 3910...  Training loss: 1.4956...  1.0331 sec/batch
# Epoch: 20/20...  Training Step: 3911...  Training loss: 1.4753...  1.0195 sec/batch
# Epoch: 20/20...  Training Step: 3912...  Training loss: 1.4416...  1.0044 sec/batch
# Epoch: 20/20...  Training Step: 3913...  Training loss: 1.4231...  1.0010 sec/batch
# Epoch: 20/20...  Training Step: 3914...  Training loss: 1.4396...  1.0021 sec/batch
# Epoch: 20/20...  Training Step: 3915...  Training loss: 1.4683...  0.9943 sec/batch
# Epoch: 20/20...  Training Step: 3916...  Training loss: 1.4589...  1.0165 sec/batch
# Epoch: 20/20...  Training Step: 3917...  Training loss: 1.4637...  0.9721 sec/batch
# Epoch: 20/20...  Training Step: 3918...  Training loss: 1.4687...  1.0021 sec/batch
# Epoch: 20/20...  Training Step: 3919...  Training loss: 1.4810...  1.0212 sec/batch
# Epoch: 20/20...  Training Step: 3920...  Training loss: 1.4599...  0.9811 sec/batch
# Epoch: 20/20...  Training Step: 3921...  Training loss: 1.4320...  1.0076 sec/batch
# Epoch: 20/20...  Training Step: 3922...  Training loss: 1.4913...  0.9887 sec/batch
# Epoch: 20/20...  Training Step: 3923...  Training loss: 1.4932...  1.0111 sec/batch
# Epoch: 20/20...  Training Step: 3924...  Training loss: 1.4678...  1.0047 sec/batch
# Epoch: 20/20...  Training Step: 3925...  Training loss: 1.4660...  1.0201 sec/batch
# Epoch: 20/20...  Training Step: 3926...  Training loss: 1.4552...  1.0180 sec/batch
# Epoch: 20/20...  Training Step: 3927...  Training loss: 1.4544...  0.9943 sec/batch
# Epoch: 20/20...  Training Step: 3928...  Training loss: 1.4628...  1.0108 sec/batch
# Epoch: 20/20...  Training Step: 3929...  Training loss: 1.4890...  1.0065 sec/batch
# Epoch: 20/20...  Training Step: 3930...  Training loss: 1.5295...  1.0202 sec/batch
# Epoch: 20/20...  Training Step: 3931...  Training loss: 1.4601...  1.0011 sec/batch
# Epoch: 20/20...  Training Step: 3932...  Training loss: 1.4630...  0.9909 sec/batch
# Epoch: 20/20...  Training Step: 3933...  Training loss: 1.4419...  1.0106 sec/batch
# Epoch: 20/20...  Training Step: 3934...  Training loss: 1.4383...  0.9987 sec/batch
# Epoch: 20/20...  Training Step: 3935...  Training loss: 1.4795...  0.9942 sec/batch
# Epoch: 20/20...  Training Step: 3936...  Training loss: 1.4682...  1.0124 sec/batch
# Epoch: 20/20...  Training Step: 3937...  Training loss: 1.4805...  1.0063 sec/batch
# Epoch: 20/20...  Training Step: 3938...  Training loss: 1.4353...  0.9964 sec/batch
# Epoch: 20/20...  Training Step: 3939...  Training loss: 1.4431...  1.0051 sec/batch
# Epoch: 20/20...  Training Step: 3940...  Training loss: 1.4914...  0.9975 sec/batch
# Epoch: 20/20...  Training Step: 3941...  Training loss: 1.4414...  0.9951 sec/batch
# Epoch: 20/20...  Training Step: 3942...  Training loss: 1.4336...  1.0277 sec/batch
# Epoch: 20/20...  Training Step: 3943...  Training loss: 1.4422...  0.9963 sec/batch
# Epoch: 20/20...  Training Step: 3944...  Training loss: 1.4585...  1.0100 sec/batch
# Epoch: 20/20...  Training Step: 3945...  Training loss: 1.4659...  1.0101 sec/batch
# Epoch: 20/20...  Training Step: 3946...  Training loss: 1.4556...  1.0120 sec/batch
# Epoch: 20/20...  Training Step: 3947...  Training loss: 1.4513...  1.0503 sec/batch
# Epoch: 20/20...  Training Step: 3948...  Training loss: 1.4361...  1.0068 sec/batch
# Epoch: 20/20...  Training Step: 3949...  Training loss: 1.4838...  1.0159 sec/batch
# Epoch: 20/20...  Training Step: 3950...  Training loss: 1.4532...  1.0170 sec/batch
# Epoch: 20/20...  Training Step: 3951...  Training loss: 1.4467...  1.0018 sec/batch
# Epoch: 20/20...  Training Step: 3952...  Training loss: 1.4575...  0.9818 sec/batch
# Epoch: 20/20...  Training Step: 3953...  Training loss: 1.4321...  0.9969 sec/batch
# Epoch: 20/20...  Training Step: 3954...  Training loss: 1.4413...  1.0104 sec/batch
# Epoch: 20/20...  Training Step: 3955...  Training loss: 1.4574...  1.0152 sec/batch
# Epoch: 20/20...  Training Step: 3956...  Training loss: 1.4347...  1.0063 sec/batch
# Epoch: 20/20...  Training Step: 3957...  Training loss: 1.4223...  0.9959 sec/batch
# Epoch: 20/20...  Training Step: 3958...  Training loss: 1.4689...  1.0150 sec/batch
# Epoch: 20/20...  Training Step: 3959...  Training loss: 1.4507...  1.0546 sec/batch
# Epoch: 20/20...  Training Step: 3960...  Training loss: 1.4356...  0.9888 sec/batch

# %% [markdown]
# #### Saved checkpoints
#
# Read up on saving and loading checkpoints here: https://www.tensorflow.org/programmers_guide/variables

# %%
tf.train.get_checkpoint_state('checkpoints')
# Out:
# model_checkpoint_path: "checkpoints/i79400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i59600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i59800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i60000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i60200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i60400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i60600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i60800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i61000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i61200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i61400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i61600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i61800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i62000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i62200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i62400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i62600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i62800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i63000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i63200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i63400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i63600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i63800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i64000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i64200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i64400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i64600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i64800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i65000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i65200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i65400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i65600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i65800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i66000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i66200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i66400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i66600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i66800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i67000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i67200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i67400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i67600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i67800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i68000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i68200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i68400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i68600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i68800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i69000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i69200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i69400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i69600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i69800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i70000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i70200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i70400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i70600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i70800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i71000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i71200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i71400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i71600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i71800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i72000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i72200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i72400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i72600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i72800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i73000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i73200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i73400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i73600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i73800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i74000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i74200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i74400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i74600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i74800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i75000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i75200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i75400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i75600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i75800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i76000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i76200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i76400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i76600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i76800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i77000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i77200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i77400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i77600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i77800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i78000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i78200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i78400_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i78600_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i78800_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i79000_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i79200_l128.ckpt"
# all_model_checkpoint_paths: "checkpoints/i79400_l128.ckpt"

# %% [markdown]
# ## Sampling
#
# Now that the network is trained, we'll can use it to generate new text. The idea is that we pass in a character, then the network will predict the next character. We can use the new one, to predict the next one. And we keep doing this to generate all new text. I also included some functionality to prime the network with some text by passing in a string and building up a state from that.
#
# The network gives us predictions for each character. To reduce noise and make things a little less random, I'm going to only choose a new character from the top N most likely characters.

# %%
def pick_top_n(preds, vocab_size, top_n=5):
    p = np.squeeze(preds)
    p[np.argsort(p)[:-top_n]] = 0
    p = p / np.sum(p)
    c = np.random.choice(vocab_size, 1, p=p)[0]
    return c

# %%
def sample(checkpoint, n_samples, lstm_size, vocab_size, prime="The "):
    samples = [c for c in prime]
    model = CharRNN(len(vocab), lstm_size=lstm_size, sampling=True)
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, checkpoint)
        new_state = sess.run(model.initial_state)
        for c in prime:
            x = np.zeros((1, 1))
            x[0,0] = vocab_to_int[c]
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

        c = pick_top_n(preds, len(vocab))
        samples.append(int_to_vocab[c])

        for i in range(n_samples):
            x[0,0] = c
            feed = {model.inputs: x,
                    model.keep_prob: 1.,
                    model.initial_state: new_state}
            preds, new_state = sess.run([model.prediction, model.final_state], 
                                         feed_dict=feed)

            c = pick_top_n(preds, len(vocab))
            samples.append(int_to_vocab[c])
        
    return ''.join(samples)

# %% [markdown]
# Here, pass in the path to a checkpoint and sample from the network.

# %%
tf.train.latest_checkpoint('checkpoints')
# Out:
# 'checkpoints/i79400_l128.ckpt'

# %%
checkpoint = tf.train.latest_checkpoint('checkpoints')
samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i79400_l128.ckpt
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1264     try:
# -> 1265       return fn(*args)
#    1266     except errors.OpError as e:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1245                                    feed_dict, fetch_list, target_list,
# -> 1246                                    status, run_metadata)
#    1247
#
# /usr/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/errors_impl.py in raise_exception_on_not_ok_status()
#     465           compat.as_text(pywrap_tensorflow.TF_Message(status)),
# --> 466           pywrap_tensorflow.TF_GetCode(status))
#     467   finally:
#
# InvalidArgumentError: Assign requires shapes of both tensors to match. lhs shape= [2048] rhs shape= [512]
# 	 [[Node: save/Assign_2 = Assign[T=DT_FLOAT, _class=["loc:@rnn/multi_rnn_cell/cell_0/lstm_cell/bias"], use_locking=true, validate_shape=true, _device="/job:localhost/replica:0/task:0/gpu:0"](rnn/multi_rnn_cell/cell_0/lstm_cell/bias, save/RestoreV2_2/_37)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-23-d2bfc3eaf15a> in <module>()
#       1 checkpoint = tf.train.latest_checkpoint('checkpoints')
# ----> 2 samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
#       3 print(samp)
#
# <ipython-input-20-8eb787ae9642> in sample(checkpoint, n_samples, lstm_size, vocab_size, prime)
#       4     saver = tf.train.Saver()
#       5     with tf.Session() as sess:
# ----> 6         saver.restore(sess, checkpoint)
#       7         new_state = sess.run(model.initial_state)
#       8         for c in prime:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py in restore(self, sess, save_path)
#    1553     logging.info("Restoring parameters from %s", save_path)
#    1554     sess.run(self.saver_def.restore_op_name,
# -> 1555              {self.saver_def.filename_tensor_name: save_path})
#    1556
#    1557   @staticmethod
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     892     try:
#     893       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 894                          run_metadata_ptr)
#     895       if run_metadata:
#     896         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1104     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1105       results = self._do_run(handle, final_targets, final_fetches,
# -> 1106                              feed_dict_tensor, options, run_metadata)
#    1107     else:
#    1108       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1257     if handle is None:
#    1258       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1259                            options, run_metadata)
#    1260     else:
#    1261       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1276         except KeyError:
#    1277           pass
# -> 1278       raise type(e)(node_def, op, message)
#    1279
#    1280   def _extend_graph(self):
#
# InvalidArgumentError: Assign requires shapes of both tensors to match. lhs shape= [2048] rhs shape= [512]
# 	 [[Node: save/Assign_2 = Assign[T=DT_FLOAT, _class=["loc:@rnn/multi_rnn_cell/cell_0/lstm_cell/bias"], use_locking=true, validate_shape=true, _device="/job:localhost/replica:0/task:0/gpu:0"](rnn/multi_rnn_cell/cell_0/lstm_cell/bias, save/RestoreV2_2/_37)]]
#
# Caused by op 'save/Assign_2', defined at:
#   File "/usr/lib/python3.5/runpy.py", line 184, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.5/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.5/dist-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "/usr/local/lib/python3.5/dist-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/usr/local/lib/python3.5/dist-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/usr/local/lib/python3.5/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.5/dist-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.5/dist-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.5/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-23-d2bfc3eaf15a>", line 2, in <module>
#     samp = sample(checkpoint, 2000, lstm_size, len(vocab), prime="Far")
#   File "<ipython-input-20-8eb787ae9642>", line 4, in sample
#     saver = tf.train.Saver()
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py", line 1140, in __init__
#     self.build()
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py", line 1172, in build
#     filename=self._filename)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py", line 688, in build
#     restore_sequentially, reshape)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py", line 419, in _AddRestoreOps
#     assign_ops.append(saveable.restore(tensors, shapes))
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py", line 155, in restore
#     self.op.get_shape().is_fully_defined())
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/state_ops.py", line 271, in assign
#     validate_shape=validate_shape)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/gen_state_ops.py", line 45, in assign
#     use_locking=use_locking, name=name)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/op_def_library.py", line 767, in apply_op
#     op_def=op_def)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py", line 2528, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py", line 1203, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): Assign requires shapes of both tensors to match. lhs shape= [2048] rhs shape= [512]
# 	 [[Node: save/Assign_2 = Assign[T=DT_FLOAT, _class=["loc:@rnn/multi_rnn_cell/cell_0/lstm_cell/bias"], use_locking=true, validate_shape=true, _device="/job:localhost/replica:0/task:0/gpu:0"](rnn/multi_rnn_cell/cell_0/lstm_cell/bias, save/RestoreV2_2/_37)]]

# %%
checkpoint = 'checkpoints/i200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)

# %%
checkpoint = 'checkpoints/i600_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i600_l512.ckpt
# Farilly wond as the prenss, what had
# allaty the moms as
# here hid bood and sand of the sace his was
# sees tile and the call and
# the panses on whith wist his hent was alloting would noth of cand and
# that the simising of that the sele and and
# a sere his
# but and an his han were some the mure and he sand and hour there the poricion a thin ham and to seid, the pitsing walle ald tho gher wat
# she said,
# and showg to the sare a sore, and would as an a the
# porstion on the sair aly all all that what ho dod
# nate her whet
# in him his
# sund and alove and had his wist wend oul at the roms the canest he dove had thay tely the soung that sel if
# the
# more,
# thet hord, the pace the sairess, hid
# hen had seid he wishing and
# sten her
# themerer hid had bone and sor time inthice the wist them and
# serped an the her with hav a so tore andersadied a steling tith of to
# all all a tall and the simered, that his to be she ded sonth had and
# with his sers wat a litt when she said, had
# shing him hen to she seed he saide hes souge

# %%
checkpoint = 'checkpoints/i1200_l512.ckpt'
samp = sample(checkpoint, 1000, lstm_size, len(vocab), prime="Far")
print(samp)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i1200_l512.ckpt
# Farlinchess
# in has sanding the convincestous of the packior. She carlid to her his atterthen.
#
# "What's she had she to dread to be
# a great."
#
# "I have been selled the sare of the midiciat, and she was to by at
# it."
#
# "Why dast all the some to be
# their propession went the best tall to to much hand to him."
#
# "They deep her and a more to tee you to might." She suddedly with a sting of where to a more and his fine shanced to himself, and she had brought the contarriant, with a supers in her atfeered on when a weller and the pass that it had net till that he had an the patiching he had taned him. "Yes, you mare a grangle of the sence,"
# said Levin, was not some homing to his bind.
# "The same that is was all and stirl a such to me. I all his moteness as she called to the
# calente, and
# this it well heard all and the senteres, and a grat finiles, and she tell
# till in her happy, and to thene was somether. I was before in the sears,. He said, and
# highed and had said, but ther as the
# seriet, and the tallin
